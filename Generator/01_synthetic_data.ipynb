# %%
import json
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random
from typing import Dict, List, Any, Optional, Union
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

print("✅ Libraries imported successfully!")
print("📊 Ready to generate synthetic sales data")
# Out:
# ✅ Libraries imported successfully!
# 📊 Ready to generate synthetic sales data

# %% [markdown]
# ## Step2- Schema Parser class

# %%
class SchemaParser:
    """
    Parses BigQuery schema JSON and provides utilities for synthetic data generation
    """
    
    def __init__(self, schema_json: Dict):
        self.schema = schema_json
        self.table_name = schema_json.get('table_name', 'unknown_table')
        self.columns = schema_json.get('columns', {})
        
    def get_column_info(self, column_name: str) -> Dict:
        """Get complete metadata for a specific column"""
        return self.columns.get(column_name, {})
    
    def get_categorical_columns(self) -> List[str]:
        """Get list of categorical columns"""
        categorical_cols = []
        for col_name, col_info in self.columns.items():
            if 'categorical_values' in col_info:
                categorical_cols.append(col_name)
        return categorical_cols
    
    def get_numerical_columns(self) -> List[str]:
        """Get list of numerical columns"""
        numerical_cols = []
        for col_name, col_info in self.columns.items():
            if 'numerical_stats' in col_info:
                numerical_cols.append(col_name)
        return numerical_cols
    
    def get_primary_key_columns(self) -> List[str]:
        """Get list of primary key columns"""
        pk_cols = []
        for col_name, col_info in self.columns.items():
            if col_info.get('is_primary_key', False):
                pk_cols.append(col_name)
        return pk_cols
    
    def get_nullable_columns(self) -> List[str]:
        """Get list of columns that can have NULL values"""
        nullable_cols = []
        for col_name, col_info in self.columns.items():
            if col_info.get('nullable', False):
                nullable_cols.append(col_name)
        return nullable_cols
    
    def print_summary(self):
        """Print a summary of the schema"""
        print(f"📋 Table: {self.table_name}")
        print(f"📊 Total Columns: {len(self.columns)}")
        print(f"🏷️  Categorical Columns: {len(self.get_categorical_columns())}")
        print(f"🔢 Numerical Columns: {len(self.get_numerical_columns())}")
        print(f"🔑 Primary Key Columns: {len(self.get_primary_key_columns())}")
        print(f"❓ Nullable Columns: {len(self.get_nullable_columns())}")
        
        print("\n📋 Column Details:")
        for col_name, col_info in self.columns.items():
            data_type = col_info.get('data_type', 'UNKNOWN')
            nullable = "✓" if col_info.get('nullable', False) else "✗"
            pk = "🔑" if col_info.get('is_primary_key', False) else ""
            
            if 'categorical_values' in col_info:
                unique_vals = len(col_info['categorical_values'])
                print(f"  • {col_name:<20} | {data_type:<10} | Nullable: {nullable} | Categories: {unique_vals} {pk}")
            elif 'numerical_stats' in col_info:
                stats = col_info['numerical_stats']
                print(f"  • {col_name:<20} | {data_type:<10} | Nullable: {nullable} | Range: {stats.get('min_value', 'N/A')}-{stats.get('max_value', 'N/A')} {pk}")
            else:
                print(f"  • {col_name:<20} | {data_type:<10} | Nullable: {nullable} {pk}")

# %% [markdown]
# ## Step 3: Data generators for categorical, numerical, and other data types

# %%
class DataGenerators:
    """
    Collection of data generators for different column types
    """
    
    @staticmethod
    def generate_categorical_data(column_info: Dict, num_rows: int) -> List[Any]:
        """
        Generate categorical data based on value distribution
        """
        categorical_values = column_info.get('categorical_values', [])
        value_distribution = column_info.get('value_distribution', {})
        nullable = column_info.get('nullable', False)
        
        if not categorical_values:
            return [None] * num_rows
        
        # Create weighted choices based on distribution
        values = list(value_distribution.keys())
        weights = list(value_distribution.values())
        
        # Normalize weights to probabilities
        total_weight = sum(weights)
        probabilities = [w / total_weight for w in weights]
        
        # Generate data
        generated_data = np.random.choice(values, size=num_rows, p=probabilities).tolist()
        
        # Handle nullable columns - introduce some NULLs if column is nullable
        if nullable:
            # Introduce ~5% NULL values for nullable columns
            null_indices = np.random.choice(num_rows, size=int(num_rows * 0.05), replace=False)
            for idx in null_indices:
                generated_data[idx] = None
        
        return generated_data
    
    @staticmethod
    def generate_numerical_data(column_info: Dict, num_rows: int) -> List[Any]:
        """
        Generate numerical data based on statistical parameters
        """
        stats = column_info.get('numerical_stats', {})
        data_type = column_info.get('data_type', 'FLOAT64')
        nullable = column_info.get('nullable', False)
        
        min_val = stats.get('min_value', 0)
        max_val = stats.get('max_value', 100)
        mean_val = stats.get('mean_value', (min_val + max_val) / 2)
        std_dev = stats.get('std_dev', (max_val - min_val) / 6)
        null_percentage = stats.get('null_percentage', 0)
        is_categorical = stats.get('is_actually_categorical', False)
        distinct_count = stats.get('distinct_count', num_rows)
        
        # Handle low-cardinality numerics as categorical
        if is_categorical or distinct_count < 50:
            # Generate discrete values within the range
            unique_values = min(distinct_count, int(max_val - min_val + 1))
            possible_values = np.linspace(min_val, max_val, unique_values)
            
            if data_type == 'INTEGER':
                possible_values = [int(v) for v in possible_values]
            
            generated_data = np.random.choice(possible_values, size=num_rows).tolist()
        else:
            # Generate continuous values using normal distribution, clipped to min/max
            generated_data = np.random.normal(mean_val, std_dev, num_rows)
            generated_data = np.clip(generated_data, min_val, max_val)
            
            if data_type == 'INTEGER':
                generated_data = np.round(generated_data).astype(int)
            
            generated_data = generated_data.tolist()
        
        # Handle NULL values based on null_percentage
        if nullable and null_percentage > 0:
            null_count = int(num_rows * (null_percentage / 100))
            null_indices = np.random.choice(num_rows, size=null_count, replace=False)
            for idx in null_indices:
                generated_data[idx] = None
        
        return generated_data
    
    @staticmethod
    def generate_primary_key_data(column_info: Dict, num_rows: int, start_id: int = 1) -> List[Any]:
        """
        Generate primary key data (sequential integers)
        """
        data_type = column_info.get('data_type', 'INTEGER')
        
        if data_type == 'STRING':
            # Generate string-based IDs
            return [f"ID_{start_id + i:06d}" for i in range(num_rows)]
        else:
            # Generate integer-based IDs
            return list(range(start_id, start_id + num_rows))
    
    @staticmethod
    def generate_datetime_data(column_info: Dict, num_rows: int, 
                             start_date: datetime = None, end_date: datetime = None) -> List[Any]:
        """
        Generate datetime data for date columns
        """
        if start_date is None:
            start_date = datetime(2022, 1, 1)
        if end_date is None:
            end_date = datetime(2025, 5, 31)
        
        nullable = column_info.get('nullable', False)
        
        # Generate random dates between start and end
        time_between_dates = end_date - start_date
        days_between_dates = time_between_dates.days
        
        generated_data = []
        for _ in range(num_rows):
            random_number_of_days = random.randrange(days_between_dates)
            random_date = start_date + timedelta(days=random_number_of_days)
            generated_data.append(random_date)
        
        # Handle nullable columns
        if nullable:
            null_indices = np.random.choice(num_rows, size=int(num_rows * 0.02), replace=False)
            for idx in null_indices:
                generated_data[idx] = None
        
        return generated_data

class DataValidator:
    """
    Validates generated data against schema constraints
    """
    
    @staticmethod
    def validate_column(data: List[Any], column_info: Dict, column_name: str) -> Dict[str, Any]:
        """
        Validate a single column's data against its schema
        """
        validation_results = {
            'column_name': column_name,
            'total_rows': len(data),
            'null_count': sum(1 for x in data if x is None),
            'null_percentage': (sum(1 for x in data if x is None) / len(data)) * 100,
            'issues': []
        }
        
        data_type = column_info.get('data_type', 'STRING')
        nullable = column_info.get('nullable', False)
        
        # Check nullable constraint
        if not nullable and validation_results['null_count'] > 0:
            validation_results['issues'].append(f"Non-nullable column has {validation_results['null_count']} NULL values")
        
        # Validate data types
        non_null_data = [x for x in data if x is not None]
        
        if 'categorical_values' in column_info:
            expected_values = set(column_info['categorical_values'])
            actual_values = set(non_null_data)
            unexpected_values = actual_values - expected_values
            if unexpected_values:
                validation_results['issues'].append(f"Unexpected categorical values: {unexpected_values}")
        
        if 'numerical_stats' in column_info:
            stats = column_info['numerical_stats']
            min_val = stats.get('min_value')
            max_val = stats.get('max_value')
            
            if min_val is not None and max_val is not None:
                out_of_range = [x for x in non_null_data if x < min_val or x > max_val]
                if out_of_range:
                    validation_results['issues'].append(f"Values out of range [{min_val}, {max_val}]: {len(out_of_range)} values")
        
        validation_results['is_valid'] = len(validation_results['issues']) == 0
        
        return validation_results
    
    @staticmethod
    def validate_dataframe(df: pd.DataFrame, schema: SchemaParser) -> Dict[str, Any]:
        """
        Validate entire dataframe against schema
        """
        overall_results = {
            'total_columns': len(df.columns),
            'total_rows': len(df),
            'validation_timestamp': datetime.now().isoformat(),
            'column_results': {},
            'summary': {'valid_columns': 0, 'invalid_columns': 0, 'total_issues': 0}
        }
        
        for column_name in df.columns:
            if column_name in schema.columns:
                column_info = schema.get_column_info(column_name)
                column_data = df[column_name].tolist()
                
                validation_result = DataValidator.validate_column(column_data, column_info, column_name)
                overall_results['column_results'][column_name] = validation_result
                
                if validation_result['is_valid']:
                    overall_results['summary']['valid_columns'] += 1
                else:
                    overall_results['summary']['invalid_columns'] += 1
                    overall_results['summary']['total_issues'] += len(validation_result['issues'])
        
        overall_results['is_valid'] = overall_results['summary']['invalid_columns'] == 0
        
        return overall_results

print("✅ Data Generators and Validators created successfully!")
print("🔧 Ready to generate and validate synthetic data")
# Out:
# ✅ Data Generators and Validators created successfully!
# 🔧 Ready to generate and validate synthetic data

# %% [markdown]
# ## Step 4: Main synthetic data generator with validation

# %%
class SyntheticDataGenerator:
    """
    Main class for generating synthetic data based on schema
    """
    
    def __init__(self, schema_json: Dict):
        self.parser = SchemaParser(schema_json)
        self.generators = DataGenerators()
        self.validator = DataValidator()
    
    def generate_synthetic_data(self, num_rows: int = 1000, 
                              start_date: datetime = None, 
                              end_date: datetime = None,
                              validate_output: bool = True) -> pd.DataFrame:
        """
        Generate synthetic data based on schema
        
        Args:
            num_rows: Number of rows to generate
            start_date: Start date for datetime columns
            end_date: End date for datetime columns  
            validate_output: Whether to validate generated data
            
        Returns:
            pandas DataFrame with synthetic data
        """
        
        print(f"🚀 Generating {num_rows:,} rows of synthetic data...")
        
        synthetic_data = {}
        
        # Process each column based on its type
        for column_name, column_info in self.parser.columns.items():
            print(f"   📝 Generating data for column: {column_name}")
            
            # Check if it's a primary key
            if column_info.get('is_primary_key', False):
                synthetic_data[column_name] = self.generators.generate_primary_key_data(
                    column_info, num_rows
                )
            
            # Check if it's categorical
            elif 'categorical_values' in column_info:
                synthetic_data[column_name] = self.generators.generate_categorical_data(
                    column_info, num_rows
                )
            
            # Check if it's numerical
            elif 'numerical_stats' in column_info:
                synthetic_data[column_name] = self.generators.generate_numerical_data(
                    column_info, num_rows
                )
            
            # Check if it's datetime (based on column name patterns)
            elif any(keyword in column_name.lower() for keyword in ['date', 'time', 'created', 'updated']):
                synthetic_data[column_name] = self.generators.generate_datetime_data(
                    column_info, num_rows, start_date, end_date
                )
            
            # Default to string generation
            else:
                # Generate generic string data
                synthetic_data[column_name] = [f"Value_{i}" for i in range(num_rows)]
        
        # Create DataFrame
        df = pd.DataFrame(synthetic_data)
        
        print(f"✅ Generated DataFrame with shape: {df.shape}")
        
        # Validate if requested
        if validate_output:
            print("🔍 Validating generated data...")
            validation_results = self.validator.validate_dataframe(df, self.parser)
            
            if validation_results['is_valid']:
                print("✅ Data validation passed!")
            else:
                print(f"⚠️  Data validation found {validation_results['summary']['total_issues']} issues")
                print("   Use show_validation_details() to see details")
                
            # Store validation results for later access
            self._last_validation = validation_results
        
        return df
    
    def show_validation_details(self):
        """Show detailed validation results from last generation"""
        if not hasattr(self, '_last_validation'):
            print("❌ No validation results available. Generate data first with validate_output=True")
            return
        
        results = self._last_validation
        print(f"\n📊 Validation Summary:")
        print(f"   ✅ Valid columns: {results['summary']['valid_columns']}")
        print(f"   ❌ Invalid columns: {results['summary']['invalid_columns']}")
        print(f"   ⚠️  Total issues: {results['summary']['total_issues']}")
        
        if results['summary']['invalid_columns'] > 0:
            print(f"\n📋 Column-level Issues:")
            for col_name, col_result in results['column_results'].items():
                if not col_result['is_valid']:
                    print(f"   🔴 {col_name}:")
                    for issue in col_result['issues']:
                        print(f"      • {issue}")
    
    def generate_sample_data(self, sample_size: int = 10) -> pd.DataFrame:
        """Generate a small sample for quick testing"""
        return self.generate_synthetic_data(num_rows=sample_size, validate_output=True)
    
    def get_column_statistics(self, df: pd.DataFrame) -> Dict:
        """Get statistics for generated data"""
        stats = {}
        
        for column in df.columns:
            col_stats = {
                'dtype': str(df[column].dtype),
                'null_count': df[column].isnull().sum(),
                'null_percentage': (df[column].isnull().sum() / len(df)) * 100,
                'unique_count': df[column].nunique()
            }
            
            if df[column].dtype in ['int64', 'float64']:
                col_stats.update({
                    'min': df[column].min(),
                    'max': df[column].max(),
                    'mean': df[column].mean(),
                    'std': df[column].std(),
                    'median': df[column].median()
                })
            
            stats[column] = col_stats
        
        return stats
    
    def compare_with_original_schema(self, df: pd.DataFrame) -> Dict:
        """Compare generated data statistics with original schema"""
        generated_stats = self.get_column_statistics(df)
        comparison = {}
        
        for column_name, col_info in self.parser.columns.items():
            if column_name not in df.columns:
                continue
                
            comparison[column_name] = {'generated': generated_stats[column_name]}
            
            # Add original stats if available
            if 'numerical_stats' in col_info:
                original_stats = col_info['numerical_stats']
                comparison[column_name]['original'] = {
                    'min': original_stats.get('min_value'),
                    'max': original_stats.get('max_value'),
                    'mean': original_stats.get('mean_value'),
                    'std': original_stats.get('std_dev'),
                    'null_percentage': original_stats.get('null_percentage', 0)
                }
            
            if 'value_distribution' in col_info:
                original_total = sum(col_info['value_distribution'].values())
                comparison[column_name]['original_distribution'] = {
                    value: (count / original_total) * 100 
                    for value, count in col_info['value_distribution'].items()
                }
        
        return comparison

# %% [markdown]
# ## Step 5: Testing with small samples

# %%
# # Test with a small sample first
# print("🧪 Testing with 10 sample rows...")
# sample_df = generator.generate_sample_data(sample_size=100)

# print("\n📋 Sample Data Preview:")
# print(sample_df)

# print("\n📊 Data Types:")
# print(sample_df.dtypes)

# print("\n📈 Basic Statistics:")
# stats = generator.get_column_statistics(sample_df)
# for col, col_stats in stats.items():
#     print(f"\n🔸 {col}:")
#     print(f"   Type: {col_stats['dtype']}")
#     print(f"   Nulls: {col_stats['null_count']} ({col_stats['null_percentage']:.1f}%)")
#     print(f"   Unique: {col_stats['unique_count']}")
    
#     if col_stats['dtype'] in ['int64', 'float64'] and 'min' in col_stats:
#         print(f"   Range: {col_stats['min']} - {col_stats['max']}")
#         print(f"   Mean: {col_stats['mean']:.2f}")

# print("\n✅ Small sample generation successful!")

# %% [markdown]
# ## Step 6: Full dataset generation

# %%
# Generate a larger dataset
# Test the schema parser
# Read JSON file
# file_path= '..\sales_data_schema_for_synthetic_Product.json'
file_path= "..\sales_data_schema_for_synthetic_layer4_FT_VW_FACT_DAILY_SALES_DATA_ANALYSIS.json"
# file_path="..\sales_data_schema_for_synthetic_layer4_FT_VW_FACT_SECONDARY_SALES_DATA.json"
# file_path= "..\sales_data_schema_for_synthetic_CUSTOMER.json"
# file_path= "..\sales_data_schema_for_synthetic_VW_FT_FACT_EXTERNAL_SALES.json"
filename=file_path.split('\\')[-1].split('.')[0]
with open(file_path, 'r') as file:
    schema_json: Dict[str, Any] = json.load(file)

print("✅ JSON file loaded successfully!")

# Initialize the generator
generator = SyntheticDataGenerator(schema_json)
print("✅ Synthetic Data Generator initialized successfully!")
print("🎯 Ready to generate pharmaceutical product data")


# Initialize and test the schema parser
parser = SchemaParser(schema_json)
parser.print_summary()
print("🚀 Generating full synthetic dataset (n rows)...")
full_df = generator.generate_synthetic_data(num_rows=100000, validate_output=True)

print("\n📋 Full Dataset Info:")
print(f"Shape: {full_df.shape}")
print(f"Memory usage: {full_df.memory_usage(deep=True).sum() / 1024:.1f} KB")

print("\n📊 Column Summary:")
for col in full_df.columns:
    dtype = full_df[col].dtype
    nulls = full_df[col].isnull().sum()
    unique = full_df[col].nunique()
    print(f"  {col:<25} | {str(dtype):<10} | Nulls: {nulls:>3} | Unique: {unique:>3}")

# Show validation details if there are any issues
generator.show_validation_details()

print("\n🎯 Dataset generation completed successfully!")

# Test the export utilities


print("💾 Testing export utilities...")

#Save full_df as CSV
full_df.to_csv(f'{filename}.csv', index=False)
# Out:
# ✅ JSON file loaded successfully!
# ✅ Synthetic Data Generator initialized successfully!
# 🎯 Ready to generate pharmaceutical product data
# 📋 Table: BI_Sales_Chatbot.layer4_FT_VW_FACT_DAILY_SALES_DATA_ANALYSIS
# 📊 Total Columns: 203
# 🏷️  Categorical Columns: 90
# 🔢 Numerical Columns: 104
# 🔑 Primary Key Columns: 0
# ❓ Nullable Columns: 203
#
# 📋 Column Details:
#   • DAILY_SALES_ID       | INTEGER    | Nullable: ✓ | Range: 1.0-10341903.0
#   • BU_ID                | STRING     | Nullable: ✓ | Categories: 9
#   • MOLECULE             | STRING     | Nullable: ✓ | Categories: 1213
#   • PTM                  | STRING     | Nullable: ✓ | Categories: 1
#   • PLI                  | STRING     | Nullable: ✓ | Categories: 2
#   • MWP                  | STRING     | Nullable: ✓ | Categories: 2
#   • COUNTRY_ID           | STRING     | Nullable: ✓ | Categories: 101
#   • ACTUAL_PLANNED_GROSS_SALES | FLOAT      | Nullable: ✓ | Range: 1.0-1.0
#   • FLAG                 | STRING     | Nullable: ✓ | Categories: 9
#   • FLAG_DESCRIPTION     | STRING     | Nullable: ✓ | Categories: 31
#   • INTERCOMPANY_FLAG    | STRING     | Nullable: ✓ | Categories: 2
#   • BUSINESS_TYPE        | STRING     | Nullable: ✓ | Categories: 2
#   • BUDGET_BUSINESS_TYPE | STRING     | Nullable: ✓ | Categories: 0
#   • BUDGET_DIVISION_NAME | STRING     | Nullable: ✓ | Categories: 0
#   • ORDER_CATEGORY       | STRING     | Nullable: ✓ | Categories: 7
#   • UPDATE_DATETIME      | TIMESTAMP  | Nullable: ✓
#   • PRODUCT_ID           | STRING     | Nullable: ✓ | Categories: 15527
#   • PROJECT_GROUP        | STRING     | Nullable: ✓ | Categories: 600
#   • BU_SKU_ID            | STRING     | Nullable: ✓ | Categories: 14453
#   • PROD_ID              | STRING     | Nullable: ✓ | Categories: 6454
#   • Bio_Flag             | STRING     | Nullable: ✓ | Categories: 2
#   • IPDO_NON_IPDO        | STRING     | Nullable: ✓ | Categories: 3
#   • SHIP_TO_PARTY_COUNTRY | STRING     | Nullable: ✓ | Categories: 167
#   • PLANT                | STRING     | Nullable: ✓ | Categories: 117
#   • CUSTOMER_CODE        | STRING     | Nullable: ✓ | Categories: 12242
#   • FK_Cust_Key          | STRING     | Nullable: ✓ | Categories: 100000
#   • FK_Cust_Key1         | STRING     | Nullable: ✓ | Categories: 11954
#   • ENTERPRISE_CUSTOMER_GROUP | STRING     | Nullable: ✓ | Categories: 10378
#   • DATE                 | DATE       | Nullable: ✓
#   • SALES_DATE           | DATE       | Nullable: ✓
#   • SALES_DATETIME       | DATETIME   | Nullable: ✓
#   • SALES_TIMESTAMP      | TIMESTAMP  | Nullable: ✓
#   • CREATED_ON           | DATE       | Nullable: ✓
#   • COMPANY_CODE         | STRING     | Nullable: ✓ | Categories: 226
#   • SALES_ORG            | STRING     | Nullable: ✓ | Categories: 10
#   • SUB_COUNTRY          | STRING     | Nullable: ✓ | Categories: 170
#   • COUNTRY              | STRING     | Nullable: ✓ | Categories: 98
#   • COUNTRY_ENTERPRISE   | STRING     | Nullable: ✓ | Categories: 69
#   • COUNTRY_GROUPING     | STRING     | Nullable: ✓ | Categories: 9
#   • REGION               | STRING     | Nullable: ✓ | Categories: 175
#   • REGION_COMBINED      | STRING     | Nullable: ✓ | Categories: 36
#   • SAP_COUNTRY_CODE     | STRING     | Nullable: ✓ | Categories: 80
#   • SUB_COUNTRY_LC       | STRING     | Nullable: ✓ | Categories: 16
#   • FOREIGN_CURRENCY     | STRING     | Nullable: ✓ | Categories: 10
#   • BASE_CURRENCY        | STRING     | Nullable: ✓ | Categories: 22
#   • BASE_UOM             | STRING     | Nullable: ✓ | Categories: 18
#   • INSTITUTION_CODE     | STRING     | Nullable: ✓ | Categories: 2165
#   • INSTITUTION_NAME     | STRING     | Nullable: ✓ | Categories: 2107
#   • CAP_EXT              | STRING     | Nullable: ✓ | Categories: 2
#   • BUDGET_BU            | STRING     | Nullable: ✓ | Categories: 5
#   • KAM_REVISED          | STRING     | Nullable: ✓ | Categories: 8
#   • ORDER_TYPE           | STRING     | Nullable: ✓ | Categories: 11
#   • SENDING_PLANT        | STRING     | Nullable: ✓ | Categories: 0
#   • RECEIVING_PLANT      | STRING     | Nullable: ✓ | Categories: 0
#   • PROFIT_CENTRE        | STRING     | Nullable: ✓ | Categories: 76
#   • MANUFACTURING_PLANT  | STRING     | Nullable: ✓ | Categories: 29
#   • TYPE                 | STRING     | Nullable: ✓ | Categories: 29
#   • SEGMENT              | STRING     | Nullable: ✓ | Categories: 4
#   • LINE_TEXT            | STRING     | Nullable: ✓ | Categories: 279
#   • WBS_ELEMENT          | STRING     | Nullable: ✓ | Categories: 461
#   • BE_MATERIAL_CODE     | STRING     | Nullable: ✓ | Categories: 445
#   • PREFERENCE           | STRING     | Nullable: ✓ | Categories: 2
#   • ACCOUNT_NUMBER       | STRING     | Nullable: ✓ | Categories: 11
#   • NET_SALES_QTY_PKS    | FLOAT      | Nullable: ✓ | Range: -507587111.0-507590251.0
#   • NET_SALES_QTY        | FLOAT      | Nullable: ✓ | Range: -9195785040.0-9195913800.0
#   • ACTUAL_QTY           | FLOAT      | Nullable: ✓ | Range: -507587111.0-507590251.0
#   • ACTUAL_QTY_UNITS     | FLOAT      | Nullable: ✓ | Range: -9195785040.0-9195913800.0
#   • ACTUAL_CAPTIVE_QTY   | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • ACTUAL_CAPTIVE_QTY_UNITS | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • GROSS_SALES_VALUE_LC | FLOAT      | Nullable: ✓ | Range: -1844188464.0-8217000000.0
#   • GROSS_SALES_VALUE_EUR | FLOAT      | Nullable: ✓ | Range: -412293.284676-980800.0
#   • GROSS_SALES_VALUE_USD | FLOAT      | Nullable: ✓ | Range: -14999757.75-98193150.0
#   • GROSS_SALES_VALUE_INR | FLOAT      | Nullable: ✓ | Range: -1277662500.0-8217000000.0
#   • NET_SALES_VALUE_LC   | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • NET_SALES_VALUE_EUR  | FLOAT      | Nullable: ✓ | Range: -74302703.81-72620115.60000001
#   • NET_SALES_VALUE_USD  | FLOAT      | Nullable: ✓ | Range: -98193150.0-98193150.0
#   • NET_SALES_VALUE_INR  | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • NET_SALES_PLUS_CUTOFF | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • CUTOFF_MINUS_PROVISIONS | FLOAT      | Nullable: ✓ | Range: -6796499.92-422463568.62
#   • GROSS_TO_NET_PERCT   | FLOAT      | Nullable: ✓ | Range: -303.0783230419239-65895333.3338927
#   • EXCHANGE_RATE        | FLOAT      | Nullable: ✓ | Range: 0.0-98.05844
#   • HEDGE_CURRENCY       | STRING     | Nullable: ✓ | Categories: 1
#   • HEDGE_AMOUNT         | FLOAT      | Nullable: ✓ | Range: -778886250.0-404158650.0
#   • SKU_GROSS_PRICE      | FLOAT      | Nullable: ✓ | Range: -12149855.441-124393523.2115
#   • SKU_NET_PRICE        | FLOAT      | Nullable: ✓ | Range: -12149855.441-124393523.2115
#   • NET_PLANNED_RATE_INR | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • NET_PLANNED_RATE_USD | FLOAT      | Nullable: ✓ | Range: -98407185.62874252-98407185.62874252
#   • NET_PLANNED_RATE_EUR | FLOAT      | Nullable: ✓ | Range: -74302703.81-72620115.60000001
#   • GROSS_PLANNED_RATE_EUR | FLOAT      | Nullable: ✓ | Range: -393417.6-980800.0
#   • GROSS_PLANNED_RATE_INR | FLOAT      | Nullable: ✓ | Range: -850900000.0-8217000000.0
#   • GROSS_PLANNED_RATE_USD | FLOAT      | Nullable: ✓ | Range: -10431649.866308723-98407185.62874252
#   • LE_QTY_DAYLEVEL      | FLOAT      | Nullable: ✓ | Range: 0.0-1066778266.7
#   • LE_QTY_PKS           | FLOAT      | Nullable: ✓ | Range: 0.0-1066778.2667
#   • LE_QTY_UNITS         | FLOAT      | Nullable: ✓ | Range: 0.0-1066778266.7
#   • LE_VALUE_LC_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -728700621.0495-1191508700.34196
#   • LE_VALUE_USD_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -21563085.634-20377339.3229
#   • LE_VALUE_INR_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -1876637283.4011-1773441675.2286
#   • LE_VALUE_EUR_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -12299540.591321109-6118039.200703226
#   • LE_SALES_QTY_NTH_MINUS_1 | FLOAT      | Nullable: ✓ | Range: 0.0-1066778266.7
#   • LE_SALES_VALUE_LC_NTH_MINUS_1 | FLOAT      | Nullable: ✓ | Range: -12299540.591321109-7295055.652687045
#   • LE_SALES_VALUE_INR_NTH_MINUS_1 | FLOAT      | Nullable: ✓ | Range: -114724285.7022-186280621.8065
#   • LE_SALES_VALUE_USD_NTH_MINUS_1 | FLOAT      | Nullable: ✓ | Range: -1389235.4465-2188961.4783
#   • LE_PLANNED_RATE_USD_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -21333147.517-19463537.3796
#   • LE_PLANNED_RATE_INR_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -1856625748.3886-1693913409.8644
#   • LE_PLANNED_RATE_EUR_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -12299540.591321109-6118039.200703226
#   • LE_QTY_PKS_V02       | FLOAT      | Nullable: ✓ | Range: 0.0-1066778.2667
#   • LE_QTY_UNITS_V02     | FLOAT      | Nullable: ✓ | Range: 0.0-1066778266.7
#   • LE_VALUE_LC_DAYLEVEL_V02 | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • LE_VALUE_USD_DAYLEVEL_V02 | FLOAT      | Nullable: ✓ | Range: -1389235.4465-2188961.4783
#   • LE_VALUE_INR_DAYLEVEL_V02 | FLOAT      | Nullable: ✓ | Range: -114724285.7022-186280621.8065
#   • LE_PLANNED_RATE_USD_DAYLEVEL_V02 | FLOAT      | Nullable: ✓ | Range: -1389235.4465-2201687.9986
#   • LE_PLANNED_RATE_INR_DAYLEVEL_V02 | FLOAT      | Nullable: ✓ | Range: -114724285.7022-187363648.6774
#   • BUDGET_QTY_DAYLEVEL  | FLOAT      | Nullable: ✓ | Range: -458.3333-96774193.80000001
#   • BUDGET_QTY_PKS       | FLOAT      | Nullable: ✓ | Range: -458.3333-72985500.0
#   • BUDGET_QTY_UNITS     | FLOAT      | Nullable: ✓ | Range: -3893.076-2474709042.82
#   • BUDGET_VALUE_LC_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -24999999.99999818-2259533249.8199997
#   • BUDGET_VALUE_USD_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -410447.761194-27895472.22
#   • BUDGET_VALUE_INR_DAYLEVEL | FLOAT      | Nullable: ✓ | Range: -29625000.0-2259533249.8199997
#   • ACTUAL_NET_SALES_LC  | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • ACTUAL_NET_SALES_EUR | FLOAT      | Nullable: ✓ | Range: -74302703.81-72620115.60000001
#   • ACTUAL_NET_SALES_USD | FLOAT      | Nullable: ✓ | Range: -98193150.0-98193150.0
#   • ACTUAL_NET_SALES_INR | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • PY_QUANTITY          | FLOAT      | Nullable: ✓ | Range: -1390720.0-3096477.0
#   • PY_NET_SALES_VAL_LC  | FLOAT      | Nullable: ✓ | Range: -1844188464.0-1762223400.0
#   • PY_NET_SALES_VAL_USD | FLOAT      | Nullable: ✓ | Range: -21563085.634-20377339.3229
#   • PY_NET_SALES_VAL_INR | FLOAT      | Nullable: ✓ | Range: -1876637283.4011-1773441675.2286
#   • PY_NET_SALES_VALUE_LC | FLOAT      | Nullable: ✓ | Range: -219165700.0-1693920123.5555556
#   • PY_NET_SALES_VALUE_USD | FLOAT      | Nullable: ✓ | Range: -1675620.0-9906008.142420016
#   • PY_NET_SALES_VALUE_INR | FLOAT      | Nullable: ✓ | Range: -143223619.5-705069540.2444799
#   • SK_PLANT             | INTEGER    | Nullable: ✓ | Range: 0.0-330.0
#   • MEDICAID             | FLOAT      | Nullable: ✓ | Range: -1372006.96-1130187.68
#   • FTS_PENALTY          | FLOAT      | Nullable: ✓ | Range: -2074569.51-2074572.47
#   • SALES_RETURN_PROVISION | FLOAT      | Nullable: ✓ | Range: -4906395.82-5357940.0
#   • SAMPLE_FLAG          | STRING     | Nullable: ✓ | Categories: 2
#   • REPORTING_MONTH      | DATE       | Nullable: ✓
#   • ENTITY               | STRING     | Nullable: ✓ | Categories: 23
#   • Net_Impact           | STRING     | Nullable: ✓ | Categories: 0
#   • BOOK_CLOSE_FLAG      | STRING     | Nullable: ✓ | Categories: 3
#   • DIVISION             | STRING     | Nullable: ✓ | Categories: 115
#   • DIVISION_NAME        | STRING     | Nullable: ✓ | Categories: 2
#   • CHANNEL_PARTNER      | STRING     | Nullable: ✓ | Categories: 12
#   • CHANNEL              | STRING     | Nullable: ✓ | Categories: 26
#   • PARTNER_FUNCTION     | STRING     | Nullable: ✓ | Categories: 3
#   • BILLING_TYPE         | STRING     | Nullable: ✓ | Categories: 33
#   • DISCOUNTS            | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • FDN                  | FLOAT      | Nullable: ✓ | Range: -3092494.66-5488196.75
#   • BONUS                | FLOAT      | Nullable: ✓ | Range: -1096823.1099999999-1645382.75
#   • GROSS_SALES_DERIVED  | FLOAT      | Nullable: ✓ | Range: -19595541.3-422463568.21999997
#   • GROSS_SALES_REPORTED | FLOAT      | Nullable: ✓ | Range: -19595541.3-422463568.21999997
#   • PD                   | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • FDN_PD               | FLOAT      | Nullable: ✓ | Range: -2267785.9299999997-5488196.48
#   • FDN_PD_BONUS         | FLOAT      | Nullable: ✓ | Range: -2279333.4299999997-5488196.48
#   • DISCOUNTED_SALES     | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • SALE_WITHOUT_DISCOUNT | FLOAT      | Nullable: ✓ | Range: -2702429.46-12077100.0
#   • MATERIAL_GROUP_1     | STRING     | Nullable: ✓ | Categories: 57
#   • INSERTED_DTTM        | TIMESTAMP  | Nullable: ✓
#   • TENDOR_FLAG          | STRING     | Nullable: ✓ | Categories: 2
#   • ACTUAL_CAPTIVE_NET_SALES_LC | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • ACTUAL_CAPTIVE_NET_SALES_USD | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • ACTUAL_CAPTIVE_NET_SALES_INR | FLOAT      | Nullable: ✓ | Range: 0.0-0.0
#   • LC_VARIANCE          | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • LE_LC_NEW            | FLOAT      | Nullable: ✓ | Range: -728700621.0495-1191508700.34196
#   • DATE_VARIANCE        | DATE       | Nullable: ✓
#   • ACTUAL_GROSS_SALES_LC | FLOAT      | Nullable: ✓ | Range: -163295000.00968984-209175532.4988299
#   • ACTUAL_GROSS_SALES_USD | FLOAT      | Nullable: ✓ | Range: -1970150.6092170395-2832259.89801803
#   • ACTUAL_GROSS_SALES_INR | FLOAT      | Nullable: ✓ | Range: -168522072.96-210051977.98
#   • ACTUAL_LE_INR        | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • ACTUAL_LE_USD        | FLOAT      | Nullable: ✓ | Range: -98193150.0-98193150.0
#   • ACTUAL_LE_EUR        | FLOAT      | Nullable: ✓ | Range: -74302703.81-72620115.60000001
#   • ACTUAL_LE_LC         | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • ACTUAL_LE_LC_NEW     | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • PLANNED_ACTUAL_LE_INR | FLOAT      | Nullable: ✓ | Range: -8217000000.0-8217000000.0
#   • PLANNED_ACTUAL_LE_USD | FLOAT      | Nullable: ✓ | Range: -98407185.62874252-98407185.62874252
#   • PLANNED_ACTUAL_LE_EUR | FLOAT      | Nullable: ✓ | Range: -74302703.81-72620115.60000001
#   • VARIANCE_BUDGET_QTY  | FLOAT      | Nullable: ✓ | Range: -458.3333-96774193.80000001
#   • VARIANCE_BUDGET_LC   | FLOAT      | Nullable: ✓ | Range: -24999999.99999818-2259533249.8199997
#   • QTY_VARIANCE         | FLOAT      | Nullable: ✓ | Range: -507587111.0-507590251.0
#   • VARIANCE_HEDGE       | FLOAT      | Nullable: ✓ | Range: -778886250.0-404158650.0
#   • LENALIDOMIDE         | STRING     | Nullable: ✓ | Categories: 2
#   • CURRENT_MONTH        | INTEGER    | Nullable: ✓ | Range: 0.0-1.0
#   • DEV_SUB_CLASS        | STRING     | Nullable: ✓ | Categories: 5
#   • ORDER_REASON_DESC    | STRING     | Nullable: ✓ | Categories: 6
#   • WBS_DESCRIPTION      | STRING     | Nullable: ✓ | Categories: 1070
#   • PLANT_NAME           | STRING     | Nullable: ✓ | Categories: 10
#   • SUB_CATEGORY         | STRING     | Nullable: ✓ | Categories: 8
#   • MIS_BU               | STRING     | Nullable: ✓ | Categories: 0
#   • RECOGNIZED_MONTH     | STRING     | Nullable: ✓ | Categories: 84
#   • FY_QTR               | STRING     | Nullable: ✓ | Categories: 4
#   • REFERENCE_DOCUMENT_NUMBER | STRING     | Nullable: ✓ | Categories: 2122
#   • SALES_ORDER          | STRING     | Nullable: ✓ | Categories: 0
#   • CATEGORY             | STRING     | Nullable: ✓ | Categories: 4
#   • DOCUMENT_NUMBER      | STRING     | Nullable: ✓ | Categories: 2120
#   • SHIP_TO_PARTY_CUSTOMER | STRING     | Nullable: ✓ | Categories: 185
#   • SHIPMENT_TYPE        | STRING     | Nullable: ✓ | Categories: 0
#   • INCO_TERMS           | STRING     | Nullable: ✓ | Categories: 0
#   • DOCUMENT_CURR        | STRING     | Nullable: ✓ | Categories: 0
#   • DISPATCH_MONTH       | STRING     | Nullable: ✓ | Categories: 0
#   • BU                   | STRING     | Nullable: ✓ | Categories: 1
#   • BD                   | STRING     | Nullable: ✓ | Categories: 20
#   • ENTITY_CURR          | STRING     | Nullable: ✓ | Categories: 0
#   • NET_AMOUNT_DC        | FLOAT      | Nullable: ✓ | Range: -59101911.0-50422915.0
#   • TOTAL_AMOUNT_LC_LC2  | FLOAT      | Nullable: ✓ | Range: -60576066.81-172687010.2
#   • HQ_NAME              | STRING     | Nullable: ✓ | Categories: 586
# 🚀 Generating full synthetic dataset (n rows)...
# 🚀 Generating 100,000 rows of synthetic data...
#    📝 Generating data for column: DAILY_SALES_ID
#    📝 Generating data for column: BU_ID
#    📝 Generating data for column: MOLECULE
#    📝 Generating data for column: PTM
#    📝 Generating data for column: PLI
#    📝 Generating data for column: MWP
#    📝 Generating data for column: COUNTRY_ID
#    📝 Generating data for column: ACTUAL_PLANNED_GROSS_SALES
#    📝 Generating data for column: FLAG
#    📝 Generating data for column: FLAG_DESCRIPTION
#    📝 Generating data for column: INTERCOMPANY_FLAG
#    📝 Generating data for column: BUSINESS_TYPE
#    📝 Generating data for column: BUDGET_BUSINESS_TYPE
#    📝 Generating data for column: BUDGET_DIVISION_NAME
#    📝 Generating data for column: ORDER_CATEGORY
#    📝 Generating data for column: UPDATE_DATETIME
#    📝 Generating data for column: PRODUCT_ID
#    📝 Generating data for column: PROJECT_GROUP
#    📝 Generating data for column: BU_SKU_ID
#    📝 Generating data for column: PROD_ID
#    📝 Generating data for column: Bio_Flag
#    📝 Generating data for column: IPDO_NON_IPDO
#    📝 Generating data for column: SHIP_TO_PARTY_COUNTRY
#    📝 Generating data for column: PLANT
#    📝 Generating data for column: CUSTOMER_CODE
#    📝 Generating data for column: FK_Cust_Key
#    📝 Generating data for column: FK_Cust_Key1
#    📝 Generating data for column: ENTERPRISE_CUSTOMER_GROUP
#    📝 Generating data for column: DATE
#    📝 Generating data for column: SALES_DATE
#    📝 Generating data for column: SALES_DATETIME
#    📝 Generating data for column: SALES_TIMESTAMP
#    📝 Generating data for column: CREATED_ON
#    📝 Generating data for column: COMPANY_CODE
#    📝 Generating data for column: SALES_ORG
#    📝 Generating data for column: SUB_COUNTRY
#    📝 Generating data for column: COUNTRY
#    📝 Generating data for column: COUNTRY_ENTERPRISE
#    📝 Generating data for column: COUNTRY_GROUPING
#    📝 Generating data for column: REGION
#    📝 Generating data for column: REGION_COMBINED
#    📝 Generating data for column: SAP_COUNTRY_CODE
#    📝 Generating data for column: SUB_COUNTRY_LC
#    📝 Generating data for column: FOREIGN_CURRENCY
#    📝 Generating data for column: BASE_CURRENCY
#    📝 Generating data for column: BASE_UOM
#    📝 Generating data for column: INSTITUTION_CODE
#    📝 Generating data for column: INSTITUTION_NAME
#    📝 Generating data for column: CAP_EXT
#    📝 Generating data for column: BUDGET_BU
#    📝 Generating data for column: KAM_REVISED
#    📝 Generating data for column: ORDER_TYPE
#    📝 Generating data for column: SENDING_PLANT
#    📝 Generating data for column: RECEIVING_PLANT
#    📝 Generating data for column: PROFIT_CENTRE
#    📝 Generating data for column: MANUFACTURING_PLANT
#    📝 Generating data for column: TYPE
#    📝 Generating data for column: SEGMENT
#    📝 Generating data for column: LINE_TEXT
#    📝 Generating data for column: WBS_ELEMENT
#    📝 Generating data for column: BE_MATERIAL_CODE
#    📝 Generating data for column: PREFERENCE
#    📝 Generating data for column: ACCOUNT_NUMBER
#    📝 Generating data for column: NET_SALES_QTY_PKS
#    📝 Generating data for column: NET_SALES_QTY
#    📝 Generating data for column: ACTUAL_QTY
#    📝 Generating data for column: ACTUAL_QTY_UNITS
#    📝 Generating data for column: ACTUAL_CAPTIVE_QTY
#    📝 Generating data for column: ACTUAL_CAPTIVE_QTY_UNITS
#    📝 Generating data for column: GROSS_SALES_VALUE_LC
#    📝 Generating data for column: GROSS_SALES_VALUE_EUR
#    📝 Generating data for column: GROSS_SALES_VALUE_USD
#    📝 Generating data for column: GROSS_SALES_VALUE_INR
#    📝 Generating data for column: NET_SALES_VALUE_LC
#    📝 Generating data for column: NET_SALES_VALUE_EUR
#    📝 Generating data for column: NET_SALES_VALUE_USD
#    📝 Generating data for column: NET_SALES_VALUE_INR
#    📝 Generating data for column: NET_SALES_PLUS_CUTOFF
#    📝 Generating data for column: CUTOFF_MINUS_PROVISIONS
#    📝 Generating data for column: GROSS_TO_NET_PERCT
#    📝 Generating data for column: EXCHANGE_RATE
#    📝 Generating data for column: HEDGE_CURRENCY
#    📝 Generating data for column: HEDGE_AMOUNT
#    📝 Generating data for column: SKU_GROSS_PRICE
#    📝 Generating data for column: SKU_NET_PRICE
#    📝 Generating data for column: NET_PLANNED_RATE_INR
#    📝 Generating data for column: NET_PLANNED_RATE_USD
#    📝 Generating data for column: NET_PLANNED_RATE_EUR
#    📝 Generating data for column: GROSS_PLANNED_RATE_EUR
#    📝 Generating data for column: GROSS_PLANNED_RATE_INR
#    📝 Generating data for column: GROSS_PLANNED_RATE_USD
#    📝 Generating data for column: LE_QTY_DAYLEVEL
#    📝 Generating data for column: LE_QTY_PKS
#    📝 Generating data for column: LE_QTY_UNITS
#    📝 Generating data for column: LE_VALUE_LC_DAYLEVEL
#    📝 Generating data for column: LE_VALUE_USD_DAYLEVEL
#    📝 Generating data for column: LE_VALUE_INR_DAYLEVEL
#    📝 Generating data for column: LE_VALUE_EUR_DAYLEVEL
#    📝 Generating data for column: LE_SALES_QTY_NTH_MINUS_1
#    📝 Generating data for column: LE_SALES_VALUE_LC_NTH_MINUS_1
#    📝 Generating data for column: LE_SALES_VALUE_INR_NTH_MINUS_1
#    📝 Generating data for column: LE_SALES_VALUE_USD_NTH_MINUS_1
#    📝 Generating data for column: LE_PLANNED_RATE_USD_DAYLEVEL
#    📝 Generating data for column: LE_PLANNED_RATE_INR_DAYLEVEL
#    📝 Generating data for column: LE_PLANNED_RATE_EUR_DAYLEVEL
#    📝 Generating data for column: LE_QTY_PKS_V02
#    📝 Generating data for column: LE_QTY_UNITS_V02
#    📝 Generating data for column: LE_VALUE_LC_DAYLEVEL_V02
#    📝 Generating data for column: LE_VALUE_USD_DAYLEVEL_V02
#    📝 Generating data for column: LE_VALUE_INR_DAYLEVEL_V02
#    📝 Generating data for column: LE_PLANNED_RATE_USD_DAYLEVEL_V02
#    📝 Generating data for column: LE_PLANNED_RATE_INR_DAYLEVEL_V02
#    📝 Generating data for column: BUDGET_QTY_DAYLEVEL
#    📝 Generating data for column: BUDGET_QTY_PKS
#    📝 Generating data for column: BUDGET_QTY_UNITS
#    📝 Generating data for column: BUDGET_VALUE_LC_DAYLEVEL
#    📝 Generating data for column: BUDGET_VALUE_USD_DAYLEVEL
#    📝 Generating data for column: BUDGET_VALUE_INR_DAYLEVEL
#    📝 Generating data for column: ACTUAL_NET_SALES_LC
#    📝 Generating data for column: ACTUAL_NET_SALES_EUR
#    📝 Generating data for column: ACTUAL_NET_SALES_USD
#    📝 Generating data for column: ACTUAL_NET_SALES_INR
#    📝 Generating data for column: PY_QUANTITY
#    📝 Generating data for column: PY_NET_SALES_VAL_LC
#    📝 Generating data for column: PY_NET_SALES_VAL_USD
#    📝 Generating data for column: PY_NET_SALES_VAL_INR
#    📝 Generating data for column: PY_NET_SALES_VALUE_LC
#    📝 Generating data for column: PY_NET_SALES_VALUE_USD
#    📝 Generating data for column: PY_NET_SALES_VALUE_INR
#    📝 Generating data for column: SK_PLANT
#    📝 Generating data for column: MEDICAID
#    📝 Generating data for column: FTS_PENALTY
#    📝 Generating data for column: SALES_RETURN_PROVISION
#    📝 Generating data for column: SAMPLE_FLAG
#    📝 Generating data for column: REPORTING_MONTH
#    📝 Generating data for column: ENTITY
#    📝 Generating data for column: Net_Impact
#    📝 Generating data for column: BOOK_CLOSE_FLAG
#    📝 Generating data for column: DIVISION
#    📝 Generating data for column: DIVISION_NAME
#    📝 Generating data for column: CHANNEL_PARTNER
#    📝 Generating data for column: CHANNEL
#    📝 Generating data for column: PARTNER_FUNCTION
#    📝 Generating data for column: BILLING_TYPE
#    📝 Generating data for column: DISCOUNTS
#    📝 Generating data for column: FDN
#    📝 Generating data for column: BONUS
#    📝 Generating data for column: GROSS_SALES_DERIVED
#    📝 Generating data for column: GROSS_SALES_REPORTED
#    📝 Generating data for column: PD
#    📝 Generating data for column: FDN_PD
#    📝 Generating data for column: FDN_PD_BONUS
#    📝 Generating data for column: DISCOUNTED_SALES
#    📝 Generating data for column: SALE_WITHOUT_DISCOUNT
#    📝 Generating data for column: MATERIAL_GROUP_1
#    📝 Generating data for column: INSERTED_DTTM
#    📝 Generating data for column: TENDOR_FLAG
#    📝 Generating data for column: ACTUAL_CAPTIVE_NET_SALES_LC
#    📝 Generating data for column: ACTUAL_CAPTIVE_NET_SALES_USD
#    📝 Generating data for column: ACTUAL_CAPTIVE_NET_SALES_INR
#    📝 Generating data for column: LC_VARIANCE
#    📝 Generating data for column: LE_LC_NEW
#    📝 Generating data for column: DATE_VARIANCE
#    📝 Generating data for column: ACTUAL_GROSS_SALES_LC
#    📝 Generating data for column: ACTUAL_GROSS_SALES_USD
#    📝 Generating data for column: ACTUAL_GROSS_SALES_INR
#    📝 Generating data for column: ACTUAL_LE_INR
#    📝 Generating data for column: ACTUAL_LE_USD
#    📝 Generating data for column: ACTUAL_LE_EUR
#    📝 Generating data for column: ACTUAL_LE_LC
#    📝 Generating data for column: ACTUAL_LE_LC_NEW
#    📝 Generating data for column: PLANNED_ACTUAL_LE_INR
#    📝 Generating data for column: PLANNED_ACTUAL_LE_USD
#    📝 Generating data for column: PLANNED_ACTUAL_LE_EUR
#    📝 Generating data for column: VARIANCE_BUDGET_QTY
#    📝 Generating data for column: VARIANCE_BUDGET_LC
#    📝 Generating data for column: QTY_VARIANCE
#    📝 Generating data for column: VARIANCE_HEDGE
#    📝 Generating data for column: LENALIDOMIDE
#    📝 Generating data for column: CURRENT_MONTH
#    📝 Generating data for column: DEV_SUB_CLASS
#    📝 Generating data for column: ORDER_REASON_DESC
#    📝 Generating data for column: WBS_DESCRIPTION
#    📝 Generating data for column: PLANT_NAME
#    📝 Generating data for column: SUB_CATEGORY
#    📝 Generating data for column: MIS_BU
#    📝 Generating data for column: RECOGNIZED_MONTH
#    📝 Generating data for column: FY_QTR
#    📝 Generating data for column: REFERENCE_DOCUMENT_NUMBER
#    📝 Generating data for column: SALES_ORDER
#    📝 Generating data for column: CATEGORY
#    📝 Generating data for column: DOCUMENT_NUMBER
#    📝 Generating data for column: SHIP_TO_PARTY_CUSTOMER
#    📝 Generating data for column: SHIPMENT_TYPE
#    📝 Generating data for column: INCO_TERMS
#    📝 Generating data for column: DOCUMENT_CURR
#    📝 Generating data for column: DISPATCH_MONTH
#    📝 Generating data for column: BU
#    📝 Generating data for column: BD
#    📝 Generating data for column: ENTITY_CURR
#    📝 Generating data for column: NET_AMOUNT_DC
#    📝 Generating data for column: TOTAL_AMOUNT_LC_LC2
#    📝 Generating data for column: HQ_NAME
# ✅ Generated DataFrame with shape: (100000, 203)
# 🔍 Validating generated data...
# ✅ Data validation passed!
#
# 📋 Full Dataset Info:
# Shape: (100000, 203)
# Memory usage: 548213.5 KB
#
# 📊 Column Summary:
#   DAILY_SALES_ID            | float64    | Nulls: 35190 | Unique: 53869
#   BU_ID                     | object     | Nulls: 5000 | Unique:   8
#   MOLECULE                  | object     | Nulls: 5000 | Unique: 899
#   PTM                       | object     | Nulls: 5000 | Unique:   1
#   PLI                       | object     | Nulls: 5000 | Unique:   2
#   MWP                       | object     | Nulls: 5000 | Unique:   2
#   COUNTRY_ID                | object     | Nulls: 5000 | Unique:  98
#   ACTUAL_PLANNED_GROSS_SALES | float64    | Nulls: 93291 | Unique:   1
#   FLAG                      | object     | Nulls: 5000 | Unique:   7
#   FLAG_DESCRIPTION          | object     | Nulls: 5000 | Unique:  27
#   INTERCOMPANY_FLAG         | object     | Nulls: 5000 | Unique:   2
#   BUSINESS_TYPE             | object     | Nulls: 5000 | Unique:   2
#   BUDGET_BUSINESS_TYPE      | object     | Nulls: 100000 | Unique:   0
#   BUDGET_DIVISION_NAME      | object     | Nulls: 100000 | Unique:   0
#   ORDER_CATEGORY            | object     | Nulls: 5000 | Unique:   7
#   UPDATE_DATETIME           | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   PRODUCT_ID                | object     | Nulls: 5000 | Unique: 8333
#   PROJECT_GROUP             | object     | Nulls: 5000 | Unique: 600
#   BU_SKU_ID                 | object     | Nulls: 5000 | Unique: 8364
#   PROD_ID                   | object     | Nulls: 5000 | Unique: 4856
#   Bio_Flag                  | object     | Nulls: 5000 | Unique:   2
#   IPDO_NON_IPDO             | object     | Nulls: 5000 | Unique:   3
#   SHIP_TO_PARTY_COUNTRY     | object     | Nulls: 5000 | Unique:  60
#   PLANT                     | object     | Nulls: 5000 | Unique:  97
#   CUSTOMER_CODE             | object     | Nulls: 5000 | Unique: 6082
#   FK_Cust_Key               | object     | Nulls: 5000 | Unique: 26083
#   FK_Cust_Key1              | object     | Nulls: 5000 | Unique: 6126
#   ENTERPRISE_CUSTOMER_GROUP | object     | Nulls: 5000 | Unique: 5074
#   DATE                      | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   SALES_DATE                | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   SALES_DATETIME            | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   SALES_TIMESTAMP           | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   CREATED_ON                | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   COMPANY_CODE              | object     | Nulls: 5000 | Unique:  22
#   SALES_ORG                 | object     | Nulls: 5000 | Unique:   9
#   SUB_COUNTRY               | object     | Nulls: 5000 | Unique: 148
#   COUNTRY                   | object     | Nulls: 5000 | Unique:  74
#   COUNTRY_ENTERPRISE        | object     | Nulls: 5000 | Unique:  62
#   COUNTRY_GROUPING          | object     | Nulls: 5000 | Unique:   9
#   REGION                    | object     | Nulls: 5000 | Unique:  51
#   REGION_COMBINED           | object     | Nulls: 5000 | Unique:  30
#   SAP_COUNTRY_CODE          | object     | Nulls: 5000 | Unique:  77
#   SUB_COUNTRY_LC            | object     | Nulls: 5000 | Unique:  16
#   FOREIGN_CURRENCY          | object     | Nulls: 5000 | Unique:   7
#   BASE_CURRENCY             | object     | Nulls: 5000 | Unique:  18
#   BASE_UOM                  | object     | Nulls: 5000 | Unique:  12
#   INSTITUTION_CODE          | object     | Nulls: 5000 | Unique: 1559
#   INSTITUTION_NAME          | object     | Nulls: 5000 | Unique: 1546
#   CAP_EXT                   | object     | Nulls: 5000 | Unique:   2
#   BUDGET_BU                 | object     | Nulls: 5000 | Unique:   5
#   KAM_REVISED               | object     | Nulls: 5000 | Unique:   8
#   ORDER_TYPE                | object     | Nulls: 5000 | Unique:  11
#   SENDING_PLANT             | object     | Nulls: 100000 | Unique:   0
#   RECEIVING_PLANT           | object     | Nulls: 100000 | Unique:   0
#   PROFIT_CENTRE             | object     | Nulls: 5000 | Unique:  76
#   MANUFACTURING_PLANT       | object     | Nulls: 5000 | Unique:  29
#   TYPE                      | object     | Nulls: 5000 | Unique:  29
#   SEGMENT                   | object     | Nulls: 5000 | Unique:   4
#   LINE_TEXT                 | object     | Nulls: 5000 | Unique: 279
#   WBS_ELEMENT               | object     | Nulls: 5000 | Unique: 461
#   BE_MATERIAL_CODE          | object     | Nulls: 5000 | Unique: 445
#   PREFERENCE                | object     | Nulls: 5000 | Unique:   2
#   ACCOUNT_NUMBER            | object     | Nulls: 5000 | Unique:  11
#   NET_SALES_QTY_PKS         | float64    | Nulls: 464 | Unique: 99536
#   NET_SALES_QTY             | float64    | Nulls: 2469 | Unique: 97531
#   ACTUAL_QTY                | float64    | Nulls: 3095 | Unique: 96905
#   ACTUAL_QTY_UNITS          | float64    | Nulls: 4656 | Unique: 95344
#   ACTUAL_CAPTIVE_QTY        | float64    | Nulls:   0 | Unique:   1
#   ACTUAL_CAPTIVE_QTY_UNITS  | float64    | Nulls:   0 | Unique:   1
#   GROSS_SALES_VALUE_LC      | float64    | Nulls: 12207 | Unique: 87793
#   GROSS_SALES_VALUE_EUR     | float64    | Nulls: 8056 | Unique: 91944
#   GROSS_SALES_VALUE_USD     | float64    | Nulls: 19739 | Unique: 80261
#   GROSS_SALES_VALUE_INR     | float64    | Nulls: 19860 | Unique: 80140
#   NET_SALES_VALUE_LC        | float64    | Nulls: 9045 | Unique: 90955
#   NET_SALES_VALUE_EUR       | float64    | Nulls:  29 | Unique: 99971
#   NET_SALES_VALUE_USD       | float64    | Nulls: 7167 | Unique: 92833
#   NET_SALES_VALUE_INR       | float64    | Nulls: 7288 | Unique: 92712
#   NET_SALES_PLUS_CUTOFF     | float64    | Nulls: 73744 | Unique: 26256
#   CUTOFF_MINUS_PROVISIONS   | float64    | Nulls: 73744 | Unique: 26256
#   GROSS_TO_NET_PERCT        | float64    | Nulls: 34610 | Unique: 33016
#   EXCHANGE_RATE             | float64    | Nulls: 93466 | Unique: 3462
#   HEDGE_CURRENCY            | object     | Nulls: 5000 | Unique:   1
#   HEDGE_AMOUNT              | float64    | Nulls: 93291 | Unique: 6709
#   SKU_GROSS_PRICE           | float64    | Nulls: 43369 | Unique: 56631
#   SKU_NET_PRICE             | float64    | Nulls: 43398 | Unique: 56602
#   NET_PLANNED_RATE_INR      | float64    | Nulls: 9987 | Unique: 90013
#   NET_PLANNED_RATE_USD      | float64    | Nulls: 9987 | Unique: 90013
#   NET_PLANNED_RATE_EUR      | float64    | Nulls: 67209 | Unique: 32791
#   GROSS_PLANNED_RATE_EUR    | float64    | Nulls: 67179 | Unique: 32821
#   GROSS_PLANNED_RATE_INR    | float64    | Nulls: 13050 | Unique: 86950
#   GROSS_PLANNED_RATE_USD    | float64    | Nulls: 10047 | Unique: 89953
#   LE_QTY_DAYLEVEL           | float64    | Nulls: 29732 | Unique: 35243
#   LE_QTY_PKS                | float64    | Nulls: 29732 | Unique: 36075
#   LE_QTY_UNITS              | float64    | Nulls: 31972 | Unique: 34103
#   LE_VALUE_LC_DAYLEVEL      | float64    | Nulls: 29766 | Unique: 70234
#   LE_VALUE_USD_DAYLEVEL     | float64    | Nulls: 29764 | Unique: 70236
#   LE_VALUE_INR_DAYLEVEL     | float64    | Nulls: 29732 | Unique: 70268
#   LE_VALUE_EUR_DAYLEVEL     | float64    | Nulls: 67179 | Unique: 32821
#   LE_SALES_QTY_NTH_MINUS_1  | float64    | Nulls:   0 | Unique: 50172
#   LE_SALES_VALUE_LC_NTH_MINUS_1 | float64    | Nulls:   0 | Unique: 100000
#   LE_SALES_VALUE_INR_NTH_MINUS_1 | float64    | Nulls:   0 | Unique: 100000
#   LE_SALES_VALUE_USD_NTH_MINUS_1 | float64    | Nulls:   0 | Unique: 100000
#   LE_PLANNED_RATE_USD_DAYLEVEL | float64    | Nulls: 26166 | Unique: 73834
#   LE_PLANNED_RATE_INR_DAYLEVEL | float64    | Nulls: 26166 | Unique: 73834
#   LE_PLANNED_RATE_EUR_DAYLEVEL | float64    | Nulls: 67131 | Unique: 32869
#   LE_QTY_PKS_V02            | float64    | Nulls:   0 | Unique: 49974
#   LE_QTY_UNITS_V02          | float64    | Nulls:   0 | Unique: 50126
#   LE_VALUE_LC_DAYLEVEL_V02  | float64    | Nulls:   0 | Unique:   1
#   LE_VALUE_USD_DAYLEVEL_V02 | float64    | Nulls:   0 | Unique: 100000
#   LE_VALUE_INR_DAYLEVEL_V02 | float64    | Nulls:   0 | Unique: 100000
#   LE_PLANNED_RATE_USD_DAYLEVEL_V02 | float64    | Nulls:   0 | Unique: 100000
#   LE_PLANNED_RATE_INR_DAYLEVEL_V02 | float64    | Nulls:   0 | Unique: 100000
#   BUDGET_QTY_DAYLEVEL       | float64    | Nulls: 29622 | Unique: 35873
#   BUDGET_QTY_PKS            | float64    | Nulls: 29622 | Unique: 36136
#   BUDGET_QTY_UNITS          | float64    | Nulls: 31851 | Unique: 34395
#   BUDGET_VALUE_LC_DAYLEVEL  | float64    | Nulls: 31450 | Unique: 68550
#   BUDGET_VALUE_USD_DAYLEVEL | float64    | Nulls: 29608 | Unique: 70392
#   BUDGET_VALUE_INR_DAYLEVEL | float64    | Nulls: 29608 | Unique: 70392
#   ACTUAL_NET_SALES_LC       | float64    | Nulls: 9864 | Unique: 90136
#   ACTUAL_NET_SALES_EUR      | float64    | Nulls:  29 | Unique: 99971
#   ACTUAL_NET_SALES_USD      | float64    | Nulls: 9863 | Unique: 90137
#   ACTUAL_NET_SALES_INR      | float64    | Nulls: 9984 | Unique: 90016
#   PY_QUANTITY               | float64    | Nulls: 69407 | Unique: 30593
#   PY_NET_SALES_VAL_LC       | float64    | Nulls: 93295 | Unique: 6705
#   PY_NET_SALES_VAL_USD      | float64    | Nulls: 93291 | Unique: 6709
#   PY_NET_SALES_VAL_INR      | float64    | Nulls: 93291 | Unique: 6709
#   PY_NET_SALES_VALUE_LC     | float64    | Nulls: 69407 | Unique: 30593
#   PY_NET_SALES_VALUE_USD    | float64    | Nulls: 69406 | Unique: 30594
#   PY_NET_SALES_VALUE_INR    | float64    | Nulls: 69406 | Unique: 30594
#   SK_PLANT                  | float64    | Nulls: 69356 | Unique: 331
#   MEDICAID                  | float64    | Nulls: 85818 | Unique: 14182
#   FTS_PENALTY               | float64    | Nulls: 71369 | Unique: 28631
#   SALES_RETURN_PROVISION    | float64    | Nulls: 85818 | Unique: 14182
#   SAMPLE_FLAG               | object     | Nulls: 5000 | Unique:   2
#   REPORTING_MONTH           | object     | Nulls:   0 | Unique: 100000
#   ENTITY                    | object     | Nulls: 5000 | Unique:  19
#   Net_Impact                | object     | Nulls: 100000 | Unique:   0
#   BOOK_CLOSE_FLAG           | object     | Nulls: 5000 | Unique:   3
#   DIVISION                  | object     | Nulls: 5000 | Unique:  98
#   DIVISION_NAME             | object     | Nulls: 5000 | Unique:   2
#   CHANNEL_PARTNER           | object     | Nulls: 5000 | Unique:  12
#   CHANNEL                   | object     | Nulls: 5000 | Unique:  25
#   PARTNER_FUNCTION          | object     | Nulls: 5000 | Unique:   3
#   BILLING_TYPE              | object     | Nulls: 5000 | Unique:  28
#   DISCOUNTS                 | float64    | Nulls: 76114 | Unique: 23886
#   FDN                       | float64    | Nulls: 93720 | Unique: 6280
#   BONUS                     | float64    | Nulls: 93720 | Unique: 6280
#   GROSS_SALES_DERIVED       | float64    | Nulls: 76114 | Unique: 23886
#   GROSS_SALES_REPORTED      | float64    | Nulls: 76117 | Unique: 23883
#   PD                        | float64    | Nulls: 76114 | Unique: 23886
#   FDN_PD                    | float64    | Nulls: 93720 | Unique: 6280
#   FDN_PD_BONUS              | float64    | Nulls: 93720 | Unique: 6280
#   DISCOUNTED_SALES          | float64    | Nulls: 76114 | Unique: 23886
#   SALE_WITHOUT_DISCOUNT     | float64    | Nulls: 76114 | Unique: 23886
#   MATERIAL_GROUP_1          | object     | Nulls: 5000 | Unique:  51
#   INSERTED_DTTM             | object     | Nulls:   0 | Unique: 100000
#   TENDOR_FLAG               | object     | Nulls: 5000 | Unique:   2
#   ACTUAL_CAPTIVE_NET_SALES_LC | float64    | Nulls:   0 | Unique:   1
#   ACTUAL_CAPTIVE_NET_SALES_USD | float64    | Nulls:   0 | Unique:   1
#   ACTUAL_CAPTIVE_NET_SALES_INR | float64    | Nulls:   0 | Unique:   1
#   LC_VARIANCE               | float64    | Nulls: 9864 | Unique: 90136
#   LE_LC_NEW                 | float64    | Nulls: 29766 | Unique: 70234
#   DATE_VARIANCE             | datetime64[ns] | Nulls: 2000 | Unique: 1246
#   ACTUAL_GROSS_SALES_LC     | float64    | Nulls:   2 | Unique: 99998
#   ACTUAL_GROSS_SALES_USD    | float64    | Nulls:   2 | Unique: 99998
#   ACTUAL_GROSS_SALES_INR    | float64    | Nulls:   2 | Unique: 99998
#   ACTUAL_LE_INR             | float64    | Nulls: 10425 | Unique: 89575
#   ACTUAL_LE_USD             | float64    | Nulls: 10303 | Unique: 89697
#   ACTUAL_LE_EUR             | float64    | Nulls: 6536 | Unique: 93464
#   ACTUAL_LE_LC              | float64    | Nulls: 10304 | Unique: 89696
#   ACTUAL_LE_LC_NEW          | float64    | Nulls: 10304 | Unique: 89696
#   PLANNED_ACTUAL_LE_INR     | float64    | Nulls: 10427 | Unique: 89573
#   PLANNED_ACTUAL_LE_USD     | float64    | Nulls: 10427 | Unique: 89573
#   PLANNED_ACTUAL_LE_EUR     | float64    | Nulls: 67200 | Unique: 32800
#   VARIANCE_BUDGET_QTY       | float64    | Nulls: 29622 | Unique: 35873
#   VARIANCE_BUDGET_LC        | float64    | Nulls: 29613 | Unique: 70387
#   QTY_VARIANCE              | float64    | Nulls: 3095 | Unique: 96905
#   VARIANCE_HEDGE            | float64    | Nulls: 93291 | Unique: 6709
#   LENALIDOMIDE              | object     | Nulls: 5000 | Unique:   2
#   CURRENT_MONTH             | int64      | Nulls:   0 | Unique:   2
#   DEV_SUB_CLASS             | object     | Nulls: 5000 | Unique:   5
#   ORDER_REASON_DESC         | object     | Nulls: 5000 | Unique:   6
#   WBS_DESCRIPTION           | object     | Nulls: 5000 | Unique: 1070
#   PLANT_NAME                | object     | Nulls: 5000 | Unique:  10
#   SUB_CATEGORY              | object     | Nulls: 5000 | Unique:   8
#   MIS_BU                    | object     | Nulls: 100000 | Unique:   0
#   RECOGNIZED_MONTH          | object     | Nulls: 5000 | Unique:  84
#   FY_QTR                    | object     | Nulls: 5000 | Unique:   4
#   REFERENCE_DOCUMENT_NUMBER | object     | Nulls: 5000 | Unique: 2122
#   SALES_ORDER               | object     | Nulls: 100000 | Unique:   0
#   CATEGORY                  | object     | Nulls: 5000 | Unique:   4
#   DOCUMENT_NUMBER           | object     | Nulls: 5000 | Unique: 2120
#   SHIP_TO_PARTY_CUSTOMER    | object     | Nulls: 5000 | Unique: 185
#   SHIPMENT_TYPE             | object     | Nulls: 100000 | Unique:   0
#   INCO_TERMS                | object     | Nulls: 100000 | Unique:   0
#   DOCUMENT_CURR             | object     | Nulls: 100000 | Unique:   0
#   DISPATCH_MONTH            | object     | Nulls: 100000 | Unique:   0
#   BU                        | object     | Nulls: 5000 | Unique:   1
#   BD                        | object     | Nulls: 5000 | Unique:  20
#   ENTITY_CURR               | object     | Nulls: 100000 | Unique:   0
#   NET_AMOUNT_DC             | float64    | Nulls: 99993 | Unique:   7
#   TOTAL_AMOUNT_LC_LC2       | float64    | Nulls: 99993 | Unique:   7
#   HQ_NAME                   | object     | Nulls: 5000 | Unique: 578
#
# 📊 Validation Summary:
#    ✅ Valid columns: 203
#    ❌ Invalid columns: 0
#    ⚠️  Total issues: 0
#
# 🎯 Dataset generation completed successfully!
# 💾 Testing export utilities...

# %%
full_df
# Out:
#        DAILY_SALES_ID    BU_ID                     MOLECULE    PTM    PLI  \
# 0                 NaN     None                   VIGABATRIN  DUMMY  False
# 1           1996854.0       EM                     NICOTINE  DUMMY  False
# 2           3875500.0     None                  RIVAROXABAN   None   None
# 3           5967811.0       EM                     AMBROXOL  DUMMY  False
# 4           1767652.0  GGINDIA                    VOGLIBOSE  DUMMY   None
# ...               ...      ...                          ...    ...    ...
# 99995       1788994.0      NAG                    KETOROLAC  DUMMY  False
# 99996             NaN      NAG                   OMEPRAZOLE  DUMMY  False
# 99997       3305411.0      NAG            DIVALPROEX SODIUM  DUMMY  False
# 99998             NaN      EUG              ZOLEDRONIC ACID  DUMMY  False
# 99999       2614328.0      EUG  ALOE BARBADENSIS+PRAMOCAINE  DUMMY   True
#
#          MWP           COUNTRY_ID  ACTUAL_PLANNED_GROSS_SALES FLAG  \
# 0      False          EUG||DE|SAP                         NaN    1
# 1      False          EUG||ES|SAP                         NaN    1
# 2      False          NAG||US|SAP                         NaN    5
# 3      False          GGI||IN|SAP                         NaN    1
# 4      False          NAG||US|SAP                         NaN    1
# ...      ...                  ...                         ...  ...
# 99995  False  EM|Australia|AU|IBP                         NaN    1
# 99996   None                 None                         1.0    1
# 99997  False     EM|Brazil|BR|IBP                         NaN    1
# 99998  False          EUG||DE|SAP                         NaN    5
# 99999  False          GGI||IN|SAP                         NaN    1
#
#               FLAG_DESCRIPTION  ... SHIPMENT_TYPE INCO_TERMS DOCUMENT_CURR  \
# 0                     SAP_CE11  ...          None       None          None
# 1                       LE_V02  ...          None       None          None
# 2                    SAP_CE11K  ...          None       None          None
# 3               QTY ADJUSTMENT  ...          None       None          None
# 4                     SAP_CE11  ...          None       None          None
# ...                        ...  ...           ...        ...           ...
# 99995                SAP_CE11K  ...          None       None          None
# 99996                       LE  ...          None       None          None
# 99997  DAILY_ENTITY_ADJUSTMENT  ...          None       None          None
# 99998                   LE_V02  ...          None       None          None
# 99999                SAP_CE11K  ...          None       None          None
#
#       DISPATCH_MONTH    BU         BD ENTITY_CURR NET_AMOUNT_DC  \
# 0               None  APSL     Ganesh        None           NaN
# 1               None  APSL    Daniel         None           NaN
# 2               None  APSL    Sivaram        None           NaN
# 3               None  APSL    Ganesh         None           NaN
# 4               None  APSL    Sivaram        None           NaN
# ...              ...   ...        ...         ...           ...
# 99995           None  None    Sivaram        None           NaN
# 99996           None  APSL   Sivaram         None           NaN
# 99997           None  APSL   Sivaram         None           NaN
# 99998           None  APSL   Sivaram         None           NaN
# 99999           None  APSL     Ganesh        None           NaN
#
#       TOTAL_AMOUNT_LC_LC2            HQ_NAME
# 0                     NaN   TM HQ - Varanasi
# 1                     NaN    TM HQ - CHENNAI
# 2                     NaN    TM HQ - Gurgaon
# 3                     NaN     TM HQ - HOWRAH
# 4                     NaN  TM HQ - Ahmedabad
# ...                   ...                ...
# 99995                 NaN    TM HQ - Chennai
# 99996                 NaN     TM HQ - JAIPUR
# 99997                 NaN               None
# 99998                 NaN    TBM HQ - Rohtak
# 99999                 NaN      TM HQ - Dhule
#
# [100000 rows x 203 columns]

# %% [markdown]
# ## Step 7: Data quality analysis and comparison with original

# %%
# Analyze the quality and distribution of generated data
print("🔍 Analyzing Generated Data Quality...")

# Compare with original schema distributions
comparison = generator.compare_with_original_schema(full_df)

print("\n📊 Distribution Analysis:")

# Analyze categorical columns
categorical_cols = generator.parser.get_categorical_columns()
for col in categorical_cols:  # Show first 3 categorical columns
    if col in full_df.columns:
        print(f"\n🏷️  {col} Distribution:")
        
        # Generated distribution
        generated_dist = full_df[col].value_counts(normalize=True, dropna=False) * 100
        
        # Original distribution
        if col in comparison and 'original_distribution' in comparison[col]:
            original_dist = comparison[col]['original_distribution']
            
            print("   Original vs Generated:")
            for value in generated_dist.index[:5]:  # Top 5 values
                orig_pct = original_dist.get(value, 0)
                gen_pct = generated_dist.get(value, 0)
                print(f"   {str(value):<30} | Orig: {orig_pct:>5.1f}% | Gen: {gen_pct:>5.1f}%")
        else:
            print("   Generated distribution:")
            for value, pct in generated_dist.head().items():
                print(f"   {str(value):<30} | {pct:>5.1f}%")

# Analyze numerical columns  
numerical_cols = generator.parser.get_numerical_columns()
for col in numerical_cols:
    if col in full_df.columns:
        print(f"\n🔢 {col} Statistics:")
        
        generated_stats = comparison[col]['generated']
        
        if 'original' in comparison[col]:
            original_stats = comparison[col]['original']
            print(f"   Min:    Original={original_stats['min']:>8.1f} | Generated={generated_stats['min']:>8.1f}")
            print(f"   Max:    Original={original_stats['max']:>8.1f} | Generated={generated_stats['max']:>8.1f}")
            print(f"   Mean:   Original={original_stats['mean']:>8.1f} | Generated={generated_stats['mean']:>8.1f}")
            print(f"   Nulls:  Original={original_stats['null_percentage']:>6.1f}% | Generated={generated_stats['null_percentage']:>6.1f}%")
        else:
            print(f"   Min: {generated_stats['min']}, Max: {generated_stats['max']}")
            print(f"   Mean: {generated_stats['mean']:.2f}, Nulls: {generated_stats['null_percentage']:.1f}%")

print("\n✅ Data quality analysis completed!")
# Out:
# 🔍 Analyzing Generated Data Quality...
#
# 📊 Distribution Analysis:
#
# 🏷️  BU_ID Distribution:
#    Original vs Generated:
#    EUG                            | Orig:  32.8% | Gen:  31.2%
#    NAG                            | Orig:  32.6% | Gen:  30.9%
#    GGINDIA                        | Orig:  25.5% | Gen:  24.2%
#    EM                             | Orig:   6.7% | Gen:   6.3%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  MOLECULE Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    OMEPRAZOLE                     | Orig:   3.8% | Gen:   3.6%
#    NICOTINE                       | Orig:   2.9% | Gen:   2.8%
#    FEXOFENADINE                   | Orig:   2.1% | Gen:   2.0%
#    OLANZAPINE                     | Orig:   1.7% | Gen:   1.6%
#
# 🏷️  PTM Distribution:
#    Original vs Generated:
#    DUMMY                          | Orig: 100.0% | Gen:  95.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  PLI Distribution:
#    Original vs Generated:
#    False                          | Orig:  87.8% | Gen:  83.4%
#    True                           | Orig:  12.2% | Gen:  11.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  MWP Distribution:
#    Original vs Generated:
#    False                          | Orig:  97.6% | Gen:  92.7%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    True                           | Orig:   2.4% | Gen:   2.3%
#
# 🏷️  COUNTRY_ID Distribution:
#    Original vs Generated:
#    NAG||US|SAP                    | Orig:  32.5% | Gen:  30.8%
#    EUG||DE|SAP                    | Orig:  27.4% | Gen:  26.3%
#    GGI||IN|SAP                    | Orig:  26.3% | Gen:  24.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    EUG||GB|SAP                    | Orig:   3.5% | Gen:   3.3%
#
# 🏷️  FLAG Distribution:
#    Original vs Generated:
#    1                              | Orig:  67.3% | Gen:  64.0%
#    2                              | Orig:  16.8% | Gen:  15.9%
#    5                              | Orig:  14.8% | Gen:  14.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    3                              | Orig:   0.7% | Gen:   0.6%
#
# 🏷️  FLAG_DESCRIPTION Distribution:
#    Original vs Generated:
#    SAP_CE11K                      | Orig:  25.3% | Gen:  23.9%
#    SAP_CE11                       | Orig:  23.1% | Gen:  22.1%
#    SAP_CE11k                      | Orig:  11.6% | Gen:  11.0%
#    LE_V01                         | Orig:   9.2% | Gen:   8.6%
#    SAP_BUDGET                     | Orig:   7.6% | Gen:   7.2%
#
# 🏷️  INTERCOMPANY_FLAG Distribution:
#    Original vs Generated:
#    N                              | Orig:  88.9% | Gen:  84.4%
#    Y                              | Orig:  11.1% | Gen:  10.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  BUSINESS_TYPE Distribution:
#    Original vs Generated:
#    API                            | Orig:  90.6% | Gen:  86.2%
#    API+                           | Orig:   9.4% | Gen:   8.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  BUDGET_BUSINESS_TYPE Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  BUDGET_DIVISION_NAME Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  ORDER_CATEGORY Distribution:
#    Original vs Generated:
#    Commercial                     | Orig:  76.3% | Gen:  72.5%
#    Developmental                  | Orig:   7.5% | Gen:   7.0%
#    Development                    | Orig:   5.7% | Gen:   5.6%
#    FY26 Launch                    | Orig:   5.8% | Gen:   5.5%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  PRODUCT_ID Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    300023454                      | Orig:   0.2% | Gen:   0.2%
#    300033286                      | Orig:   0.2% | Gen:   0.2%
#    300024357                      | Orig:   0.2% | Gen:   0.2%
#    300023273                      | Orig:   0.2% | Gen:   0.2%
#
# 🏷️  PROJECT_GROUP Distribution:
#    Original vs Generated:
#    Adjustments                    | Orig:  29.7% | Gen:  28.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Sanofi - FTE                   | Orig:   2.0% | Gen:   1.9%
#    Novartis - FTE                 | Orig:   1.8% | Gen:   1.7%
#    Novartis - FFS                 | Orig:   1.4% | Gen:   1.4%
#
# 🏷️  BU_SKU_ID Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    EUG                            | Orig:   1.0% | Gen:   0.9%
#    India300023454                 | Orig:   0.2% | Gen:   0.2%
#    India300033286                 | Orig:   0.2% | Gen:   0.2%
#    India300023273                 | Orig:   0.2% | Gen:   0.2%
#
# 🏷️  PROD_ID Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    300021393                      | Orig:   0.2% | Gen:   0.2%
#    300021768                      | Orig:   0.1% | Gen:   0.1%
#    300021392                      | Orig:   0.2% | Gen:   0.1%
#    300001820                      | Orig:   0.1% | Gen:   0.1%
#
# 🏷️  Bio_Flag Distribution:
#    Original vs Generated:
#    Non-Bio                        | Orig:  99.5% | Gen:  94.5%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Bio                            | Orig:   0.5% | Gen:   0.5%
#
# 🏷️  IPDO_NON_IPDO Distribution:
#    Original vs Generated:
#    Non-IPDO                       | Orig:  51.8% | Gen:  49.2%
#    IPDO                           | Orig:  48.2% | Gen:  45.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    NON-IPDO                       | Orig:   0.1% | Gen:   0.1%
#
# 🏷️  SHIP_TO_PARTY_COUNTRY Distribution:
#    Original vs Generated:
#    IN                             | Orig:  99.8% | Gen:  94.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#                                   | Orig:   0.0% | Gen:   0.0%
#    US                             | Orig:   0.0% | Gen:   0.0%
#    TR                             | Orig:   0.0% | Gen:   0.0%
#
# 🏷️  PLANT Distribution:
#    Original vs Generated:
#    6090                           | Orig:  17.4% | Gen:  16.6%
#    6038                           | Orig:  15.1% | Gen:  14.4%
#    2014                           | Orig:  11.8% | Gen:  11.3%
#    2003                           | Orig:   6.4% | Gen:   6.2%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  CUSTOMER_CODE Distribution:
#    Original vs Generated:
#    OTHERS                         | Orig:   7.8% | Gen:   7.4%
#    NULL                           | Orig:   7.4% | Gen:   7.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    370273                         | Orig:   3.7% | Gen:   3.5%
#    370182                         | Orig:   2.7% | Gen:   2.5%
#
# 🏷️  FK_Cust_Key Distribution:
#    Original vs Generated:
#    OTHERS|31                      | Orig:   5.7% | Gen:   5.4%
#    NULL|31                        | Orig:   5.3% | Gen:   5.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    370273|31                      | Orig:   3.3% | Gen:   3.2%
#    370182|31                      | Orig:   2.4% | Gen:   2.3%
#
# 🏷️  FK_Cust_Key1 Distribution:
#    Original vs Generated:
#    OTHERS|31                      | Orig:   5.7% | Gen:   5.5%
#    NULL|31                        | Orig:   5.3% | Gen:   5.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    370273|31                      | Orig:   3.3% | Gen:   3.2%
#    370182|31                      | Orig:   2.4% | Gen:   2.3%
#
# 🏷️  ENTERPRISE_CUSTOMER_GROUP Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Cencora                        | Orig:   5.0% | Gen:   4.6%
#    Phoenix                        | Orig:   3.9% | Gen:   3.8%
#    Others                         | Orig:   3.8% | Gen:   3.6%
#    Noweda                         | Orig:   3.8% | Gen:   3.5%
#
# 🏷️  COMPANY_CODE Distribution:
#    Original vs Generated:
#    1000                           | Orig:  31.6% | Gen:  29.9%
#    3005                           | Orig:  26.0% | Gen:  24.8%
#                                   | Orig:  17.2% | Gen:  16.3%
#    2000                           | Orig:  13.4% | Gen:  12.8%
#                                   | Orig:   6.9% | Gen:   6.5%
#
# 🏷️  SALES_ORG Distribution:
#    Original vs Generated:
#    1000                           | Orig:  67.0% | Gen:  63.7%
#    1007                           | Orig:  31.8% | Gen:  30.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    5000                           | Orig:   0.5% | Gen:   0.5%
#    1025                           | Orig:   0.3% | Gen:   0.3%
#
# 🏷️  SUB_COUNTRY Distribution:
#    Original vs Generated:
#    GERMANY                        | Orig:  63.5% | Gen:  60.2%
#    UK                             | Orig:   5.3% | Gen:   5.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    GB                             | Orig:   2.5% | Gen:   2.4%
#    UKOL                           | Orig:   2.2% | Gen:   2.2%
#
# 🏷️  COUNTRY Distribution:
#    Original vs Generated:
#    USA                            | Orig:  31.5% | Gen:  29.7%
#    Germany                        | Orig:  26.9% | Gen:  25.6%
#    INDIA                          | Orig:  25.5% | Gen:  24.4%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    United Kingdom                 | Orig:   3.5% | Gen:   3.3%
#
# 🏷️  COUNTRY_ENTERPRISE Distribution:
#    Original vs Generated:
#    USA                            | Orig:  31.4% | Gen:  30.1%
#    Germany                        | Orig:  26.8% | Gen:  25.2%
#    GGINDIA                        | Orig:  25.6% | Gen:  24.5%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    United Kingdom                 | Orig:   3.5% | Gen:   3.2%
#
# 🏷️  COUNTRY_GROUPING Distribution:
#    Original vs Generated:
#    USA                            | Orig:  31.3% | Gen:  29.6%
#    Germany                        | Orig:  26.7% | Gen:  25.4%
#    GGINDIA                        | Orig:  25.5% | Gen:  24.4%
#    🠈 Others                       | Orig:   9.4% | Gen:   8.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  REGION Distribution:
#    Original vs Generated:
#    NAG                            | Orig:  32.9% | Gen:  31.2%
#    Germany                        | Orig:  27.0% | Gen:  25.6%
#    GGINDIA                        | Orig:  25.7% | Gen:  24.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    UK                             | Orig:   3.5% | Gen:   3.4%
#
# 🏷️  REGION_COMBINED Distribution:
#    Original vs Generated:
#    NAG                            | Orig:  33.0% | Gen:  31.3%
#    Germany                        | Orig:  27.0% | Gen:  25.8%
#    GGINDIA                        | Orig:  25.8% | Gen:  24.7%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    UK                             | Orig:   3.5% | Gen:   3.3%
#
# 🏷️  SAP_COUNTRY_CODE Distribution:
#    Original vs Generated:
#    US                             | Orig:  44.2% | Gen:  41.7%
#    DE                             | Orig:  37.7% | Gen:  36.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    GB                             | Orig:   4.9% | Gen:   4.6%
#    CA                             | Orig:   1.4% | Gen:   1.3%
#
# 🏷️  SUB_COUNTRY_LC Distribution:
#    Original vs Generated:
#    INR                            | Orig:  33.9% | Gen:  32.3%
#    EUR                            | Orig:  32.5% | Gen:  30.8%
#    USD                            | Orig:  27.2% | Gen:  25.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    RUB                            | Orig:   1.2% | Gen:   1.2%
#
# 🏷️  FOREIGN_CURRENCY Distribution:
#    Original vs Generated:
#    USD                            | Orig:  97.1% | Gen:  92.3%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    RUB                            | Orig:   1.7% | Gen:   1.6%
#    CAD                            | Orig:   0.6% | Gen:   0.6%
#    UAH                            | Orig:   0.4% | Gen:   0.3%
#
# 🏷️  BASE_CURRENCY Distribution:
#    Original vs Generated:
#    INR                            | Orig:  38.2% | Gen:  36.0%
#    USD                            | Orig:  32.3% | Gen:  31.0%
#    EUR                            | Orig:  26.1% | Gen:  24.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    GBP                            | Orig:   2.8% | Gen:   2.6%
#
# 🏷️  BASE_UOM Distribution:
#    Original vs Generated:
#    SU                             | Orig:  58.3% | Gen:  55.2%
#                                   | Orig:  38.1% | Gen:  36.3%
#    None                           | Orig:   0.0% | Gen:   5.0%
#                                   | Orig:   3.3% | Gen:   3.2%
#    NO                             | Orig:   0.1% | Gen:   0.1%
#
# 🏷️  INSTITUTION_CODE Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    0000502381                     | Orig:   3.6% | Gen:   3.4%
#    0000501040                     | Orig:   1.9% | Gen:   1.7%
#    0000503488                     | Orig:   1.3% | Gen:   1.3%
#    0000502496                     | Orig:   1.2% | Gen:   1.2%
#
# 🏷️  INSTITUTION_NAME Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    MMGPA (Maharashtra Medical Goods | Orig:   3.6% | Gen:   3.4%
#    Apollo Hospitals - New Delhi   | Orig:   1.9% | Gen:   1.8%
#    Asian Heart Institute          | Orig:   1.3% | Gen:   1.3%
#    Medplus-Hyderabad              | Orig:   1.2% | Gen:   1.2%
#
# 🏷️  CAP_EXT Distribution:
#    Original vs Generated:
#    EXTERNAL                       | Orig:  97.6% | Gen:  92.7%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    External                       | Orig:   2.4% | Gen:   2.3%
#
# 🏷️  BUDGET_BU Distribution:
#    Original vs Generated:
#    Generics                       | Orig:  85.4% | Gen:  81.0%
#    API+                           | Orig:   9.2% | Gen:   8.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Innovator                      | Orig:   3.7% | Gen:   3.5%
#    API +                          | Orig:   1.7% | Gen:   1.6%
#
# 🏷️  KAM_REVISED Distribution:
#    Original vs Generated:
#    Others                         | Orig:  55.1% | Gen:  52.1%
#    No                             | Orig:  20.3% | Gen:  19.4%
#    Key                            | Orig:  15.6% | Gen:  14.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Yes                            | Orig:   4.6% | Gen:   4.5%
#
# 🏷️  ORDER_TYPE Distribution:
#    Original vs Generated:
#    Commercial                     | Orig:  78.2% | Gen:  74.6%
#    Development                    | Orig:   9.9% | Gen:   9.4%
#    Repeater                       | Orig:   6.6% | Gen:   6.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    API+                           | Orig:   1.8% | Gen:   1.7%
#
# 🏷️  SENDING_PLANT Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  RECEIVING_PLANT Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  PROFIT_CENTRE Distribution:
#    Original vs Generated:
#    0010060301                     | Orig:  13.9% | Gen:  13.4%
#    0010050301                     | Orig:  13.3% | Gen:  12.4%
#    0010020301                     | Orig:   8.4% | Gen:   8.0%
#    0010010301                     | Orig:   7.0% | Gen:   6.6%
#    0091161406                     | Orig:   6.0% | Gen:   5.7%
#
# 🏷️  MANUFACTURING_PLANT Distribution:
#    Original vs Generated:
#    1006                           | Orig:  15.1% | Gen:  14.3%
#    1002                           | Orig:  11.2% | Gen:  10.5%
#    6038                           | Orig:  10.2% | Gen:   9.7%
#    1014                           | Orig:   8.5% | Gen:   8.0%
#    1001                           | Orig:   8.2% | Gen:   7.8%
#
# 🏷️  TYPE Distribution:
#    Original vs Generated:
#    FTE                            | Orig:  50.0% | Gen:  47.4%
#    Cost of consumable             | Orig:  36.0% | Gen:  34.1%
#    Licensing fee                  | Orig:  12.0% | Gen:  11.5%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Milestone                      | Orig:   0.6% | Gen:   0.5%
#
# 🏷️  SEGMENT Distribution:
#    Original vs Generated:
#    Research Funding               | Orig:  50.7% | Gen:  48.0%
#    Research Funding - Reimb       | Orig:  36.6% | Gen:  34.9%
#    Licensing                      | Orig:  12.1% | Gen:  11.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Pre-clinical milestone         | Orig:   0.6% | Gen:   0.6%
#
# 🏷️  LINE_TEXT Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Olema Reclass-Transfer from Service to license fee | Orig:   2.8% | Gen:   2.7%
#    Cost of consumable used for the project | Orig:   1.4% | Gen:   1.4%
#    Olema Forex Reclass on $8M upfront billing | Orig:   1.2% | Gen:   1.2%
#    Licensing fee -Exelixis Forex Reclass on $1M Exclu | Orig:   1.2% | Gen:   1.1%
#
# 🏷️  WBS_ELEMENT Distribution:
#    Original vs Generated:
#    CUS20825                       | Orig:  13.2% | Gen:  12.4%
#    CUS20503                       | Orig:  10.1% | Gen:   9.6%
#    CUS20570                       | Orig:   7.1% | Gen:   6.8%
#    CUS21099                       | Orig:   7.1% | Gen:   6.7%
#    CUS20372                       | Orig:   6.7% | Gen:   6.4%
#
# 🏷️  BE_MATERIAL_CODE Distribution:
#    Original vs Generated:
#    000000000300102097             | Orig:   8.0% | Gen:   7.7%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    000000000350000035             | Orig:   4.1% | Gen:   3.9%
#    000000000350003313             | Orig:   3.9% | Gen:   3.7%
#    000000000200003331             | Orig:   3.6% | Gen:   3.4%
#
# 🏷️  PREFERENCE Distribution:
#    Original vs Generated:
#    Consider                       | Orig:  86.1% | Gen:  81.9%
#    Do not consider                | Orig:  13.9% | Gen:  13.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  ACCOUNT_NUMBER Distribution:
#    Original vs Generated:
#    32010024                       | Orig:  61.3% | Gen:  58.3%
#    31010052                       | Orig:  24.2% | Gen:  22.9%
#    32010043                       | Orig:   8.6% | Gen:   8.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    31010005                       | Orig:   2.6% | Gen:   2.4%
#
# 🏷️  HEDGE_CURRENCY Distribution:
#    Original vs Generated:
#    INR                            | Orig: 100.0% | Gen:  95.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  SAMPLE_FLAG Distribution:
#    Original vs Generated:
#    N                              | Orig:  82.2% | Gen:  77.7%
#    Y                              | Orig:  17.8% | Gen:  17.3%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  ENTITY Distribution:
#    Original vs Generated:
#    DRL INC                        | Orig:  64.3% | Gen:  61.0%
#    BUDGET                         | Orig:  17.2% | Gen:  16.3%
#    LE                             | Orig:  17.0% | Gen:  16.2%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    CANADA                         | Orig:   0.7% | Gen:   0.7%
#
# 🏷️  Net_Impact Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  BOOK_CLOSE_FLAG Distribution:
#    Original vs Generated:
#    CLOSED                         | Orig:  68.7% | Gen:  65.0%
#    NA                             | Orig:  31.1% | Gen:  29.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    UNCLOSED                       | Orig:   0.2% | Gen:   0.2%
#
# 🏷️  DIVISION Distribution:
#    Original vs Generated:
#    31                             | Orig:  42.4% | Gen:  40.1%
#    40                             | Orig:  13.7% | Gen:  13.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Maximus                        | Orig:   3.5% | Gen:   3.2%
#    Zenura                         | Orig:   3.0% | Gen:   2.9%
#
# 🏷️  DIVISION_NAME Distribution:
#    Original vs Generated:
#    GENERICS                       | Orig:  96.3% | Gen:  91.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    INNOVATOR                      | Orig:   3.7% | Gen:   3.4%
#
# 🏷️  CHANNEL_PARTNER Distribution:
#    Original vs Generated:
#    Trade                          | Orig:  79.0% | Gen:  75.1%
#    Medvol                         | Orig:   5.7% | Gen:   5.4%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Hospital                       | Orig:   4.8% | Gen:   4.6%
#    Retail Business                | Orig:   3.5% | Gen:   3.2%
#
# 🏷️  CHANNEL Distribution:
#    Original vs Generated:
#    Retail                         | Orig:  28.5% | Gen:  27.2%
#    Rx                             | Orig:  25.4% | Gen:  24.1%
#    Trade                          | Orig:  18.0% | Gen:  17.1%
#    OTC                            | Orig:  12.3% | Gen:  11.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  PARTNER_FUNCTION Distribution:
#    Original vs Generated:
#    ZH                             | Orig:  63.8% | Gen:  60.7%
#    ZI                             | Orig:  20.7% | Gen:  19.5%
#    ZR                             | Orig:  15.5% | Gen:  14.8%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  BILLING_TYPE Distribution:
#    Original vs Generated:
#    ZCOR                           | Orig:  55.3% | Gen:  52.7%
#    ZREW                           | Orig:  27.4% | Gen:  26.1%
#    ZFDN                           | Orig:   5.8% | Gen:   5.5%
#    ZCOI                           | Orig:   5.7% | Gen:   5.3%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  MATERIAL_GROUP_1 Distribution:
#    Original vs Generated:
#    031                            | Orig:   9.6% | Gen:   9.0%
#    056                            | Orig:   7.9% | Gen:   7.3%
#    035                            | Orig:   7.7% | Gen:   7.2%
#    034                            | Orig:   7.4% | Gen:   7.1%
#    028                            | Orig:   7.3% | Gen:   6.9%
#
# 🏷️  TENDOR_FLAG Distribution:
#    Original vs Generated:
#    N                              | Orig:  98.8% | Gen:  93.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Y                              | Orig:   1.2% | Gen:   1.1%
#
# 🏷️  LENALIDOMIDE Distribution:
#    Original vs Generated:
#    EXCL. LENALIDOMIDE             | Orig: 100.0% | Gen:  94.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    LENALIDOMIDE                   | Orig:   0.0% | Gen:   0.1%
#
# 🏷️  DEV_SUB_CLASS Distribution:
#    Original vs Generated:
#    Commercial                     | Orig:  79.5% | Gen:  75.5%
#    Repeater                       | Orig:  16.5% | Gen:  15.6%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    New product                    | Orig:   2.6% | Gen:   2.5%
#    New Product                    | Orig:   1.2% | Gen:   1.1%
#
# 🏷️  ORDER_REASON_DESC Distribution:
#    Original vs Generated:
#    Commercial                     | Orig:  71.8% | Gen:  68.0%
#    Developmental                  | Orig:   9.1% | Gen:   8.8%
#    FY26 Launch                    | Orig:   7.0% | Gen:   6.7%
#    Development                    | Orig:   6.5% | Gen:   6.2%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  WBS_DESCRIPTION Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    BPG Bio-FTE                    | Orig:   2.1% | Gen:   2.1%
#    P-441                          | Orig:   1.9% | Gen:   1.9%
#    P-439                          | Orig:   1.8% | Gen:   1.7%
#    P-440                          | Orig:   1.8% | Gen:   1.7%
#
# 🏷️  PLANT_NAME Distribution:
#    Original vs Generated:
#    APSL Hyderabad                 | Orig:  47.9% | Gen:  46.0%
#    APSL -Bangalore                | Orig:  46.9% | Gen:  44.2%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    APSL CDMO- Biologics           | Orig:   1.4% | Gen:   1.3%
#    CTO Unit 3                     | Orig:   1.3% | Gen:   1.2%
#
# 🏷️  SUB_CATEGORY Distribution:
#    Original vs Generated:
#    FTE                            | Orig:  44.8% | Gen:  42.7%
#    FFS                            | Orig:  27.7% | Gen:  26.1%
#    Drug Substance                 | Orig:  20.9% | Gen:  20.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#    Drug Product                   | Orig:   4.9% | Gen:   4.5%
#
# 🏷️  MIS_BU Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  RECOGNIZED_MONTH Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    2025-03                        | Orig:   4.6% | Gen:   4.4%
#    2024-10                        | Orig:   3.8% | Gen:   3.6%
#    2025-01                        | Orig:   3.8% | Gen:   3.6%
#    2025-02                        | Orig:   3.7% | Gen:   3.4%
#
# 🏷️  FY_QTR Distribution:
#    Original vs Generated:
#    Q4                             | Orig:  27.1% | Gen:  25.6%
#    Q3                             | Orig:  24.7% | Gen:  23.5%
#    Q1                             | Orig:  24.0% | Gen:  23.0%
#    Q2                             | Orig:  24.2% | Gen:  22.9%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  REFERENCE_DOCUMENT_NUMBER Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    0800002130                     | Orig:   1.0% | Gen:   1.0%
#    0800002285                     | Orig:   1.0% | Gen:   1.0%
#    0800004126                     | Orig:   1.0% | Gen:   0.9%
#    0800003680                     | Orig:   1.0% | Gen:   0.9%
#
# 🏷️  SALES_ORDER Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  CATEGORY Distribution:
#    Original vs Generated:
#    Discovery Services             | Orig:  43.1% | Gen:  40.9%
#    CDMO                           | Orig:  26.8% | Gen:  25.6%
#    NBE                            | Orig:  17.9% | Gen:  17.0%
#    Biologics CDMO                 | Orig:  12.2% | Gen:  11.5%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  DOCUMENT_NUMBER Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    0800004126                     | Orig:   1.0% | Gen:   1.0%
#    0800003680                     | Orig:   1.0% | Gen:   0.9%
#    0800002285                     | Orig:   1.0% | Gen:   0.9%
#    0800002130                     | Orig:   1.0% | Gen:   0.9%
#
# 🏷️  SHIP_TO_PARTY_CUSTOMER Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    0000152008                     | Orig:   4.8% | Gen:   4.5%
#    0000114858                     | Orig:   4.5% | Gen:   4.3%
#    0000173539                     | Orig:   3.6% | Gen:   3.4%
#    0000181609                     | Orig:   3.6% | Gen:   3.3%
#
# 🏷️  SHIPMENT_TYPE Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  INCO_TERMS Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  DOCUMENT_CURR Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  DISPATCH_MONTH Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  BU Distribution:
#    Original vs Generated:
#    APSL                           | Orig: 100.0% | Gen:  95.0%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  BD Distribution:
#    Original vs Generated:
#     Sivaram                       | Orig:  39.2% | Gen:  37.3%
#    Sivaram                        | Orig:  23.6% | Gen:  22.3%
#    Ganesh                         | Orig:  13.6% | Gen:  13.0%
#    Daniel                         | Orig:   5.4% | Gen:   5.1%
#    None                           | Orig:   0.0% | Gen:   5.0%
#
# 🏷️  ENTITY_CURR Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen: 100.0%
#
# 🏷️  HQ_NAME Distribution:
#    Original vs Generated:
#    None                           | Orig:   0.0% | Gen:   5.0%
#    TM HQ - Kolkata                | Orig:   2.4% | Gen:   2.3%
#    TM HQ - Hyderabad              | Orig:   2.2% | Gen:   2.1%
#    TM HQ - Bangalore              | Orig:   2.2% | Gen:   2.1%
#    TM HQ - Pune                   | Orig:   1.9% | Gen:   1.8%
#
# 🔢 DAILY_SALES_ID Statistics:
#    Min:    Original=     1.0 | Generated=     1.0
#    Max:    Original=10341903.0 | Generated=10341903.0
#    Mean:   Original=2327344.0 | Generated=2542090.1
#    Nulls:  Original=  35.2% | Generated=  35.2%
#
# 🔢 ACTUAL_PLANNED_GROSS_SALES Statistics:
#    Min:    Original=     1.0 | Generated=     1.0
#    Max:    Original=     1.0 | Generated=     1.0
#    Mean:   Original=     1.0 | Generated=     1.0
#    Nulls:  Original=  93.3% | Generated=  93.3%
#
# 🔢 NET_SALES_QTY_PKS Statistics:
#    Min:    Original=-507587111.0 | Generated=-748602.5
#    Max:    Original=507590251.0 | Generated=763950.6
#    Mean:   Original=   351.5 | Generated=   622.7
#    Nulls:  Original=   0.5% | Generated=   0.5%
#
# 🔢 NET_SALES_QTY Statistics:
#    Min:    Original=-9195785040.0 | Generated=-10348418.8
#    Max:    Original=9195913800.0 | Generated=10647312.1
#    Mean:   Original=  8694.8 | Generated= -8717.6
#    Nulls:  Original=   2.5% | Generated=   2.5%
#
# 🔢 ACTUAL_QTY Statistics:
#    Min:    Original=-507587111.0 | Generated=-831987.8
#    Max:    Original=507590251.0 | Generated=812617.1
#    Mean:   Original=   129.3 | Generated=   455.5
#    Nulls:  Original=   3.1% | Generated=   3.1%
#
# 🔢 ACTUAL_QTY_UNITS Statistics:
#    Min:    Original=-9195785040.0 | Generated=-9509631.7
#    Max:    Original=9195913800.0 | Generated=10566977.3
#    Mean:   Original=  4198.5 | Generated= -2446.2
#    Nulls:  Original=   4.7% | Generated=   4.7%
#
# 🔢 ACTUAL_CAPTIVE_QTY Statistics:
#    Min:    Original=     0.0 | Generated=     0.0
#    Max:    Original